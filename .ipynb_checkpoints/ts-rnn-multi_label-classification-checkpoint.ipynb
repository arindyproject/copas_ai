# %% [markdown]
# #                                  timeseris Multi Label Clasification - RNN

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import os
import numpy as np

# %%
file_name = "microsoft_stock_data"
root_folder = f'timeseris/multi-label-clasification/rnn/{file_name}/' 
os.makedirs(root_folder, exist_ok=True)

df = pd.read_csv('sample_data/'+file_name+'.csv')

df.head()
# Out:
#         Date     Close      High       Low      Open    Volume
# 0  3/26/1986  0.057906  0.058437  0.055781  0.056312  22752000
# 1  3/27/1986  0.058969  0.058969  0.057906  0.057906  16848000
# 2  3/31/1986  0.058437  0.058969  0.057375  0.058969  12873600
# 3   4/1/1986  0.057906  0.058437  0.057906  0.058437  11088000
# 4   4/2/1986  0.058437  0.059500  0.057906  0.057906  27014400

# %% [markdown]
# #### Pilih tahun mulai data

# %%
# Pastikan kolom Date dalam format datetime
df['Date'] = pd.to_datetime(df['Date'])

# Filter data mulai dari tahun 2000
df = df[df['Date'] >= '2000-01-01']

# (Opsional) urutkan berdasarkan tanggal
df = df.sort_values('Date').reset_index(drop=True)
df.head()
# Out:
#         Date      Close       High        Low       Open    Volume
# 0 2000-01-03  35.668076  36.299200  34.271952  35.916700  53228400
# 1 2000-01-04  34.463207  35.840206  34.348457  34.750082  54119000
# 2 2000-01-05  34.826591  35.610716  33.468718  34.004217  64059600
# 3 2000-01-06  33.659954  34.845702  33.162705  34.329328  54976600
# 4 2000-01-07  34.099846  34.348471  32.837597  33.239222  62013600

# %% [markdown]
# #### tambahkan status green, red, dan netral || DayName

# %%
# === Tambahkan kolom nama hari ===
df['Day'] =  df['Date'].dt.day_name()  # bahasa Inggris

# Buat kondisi
conditions = [
    df['Close'] > df['Open'],
    df['Close'] < df['Open'],
    df['Close'] == df['Open']
]
choices = ['green', 'red', 'red']

df['Status'] = np.select(conditions, choices)
df.head()
# Out:
#         Date      Close       High        Low       Open    Volume        Day  \
# 0 2000-01-03  35.668076  36.299200  34.271952  35.916700  53228400     Monday
# 1 2000-01-04  34.463207  35.840206  34.348457  34.750082  54119000    Tuesday
# 2 2000-01-05  34.826591  35.610716  33.468718  34.004217  64059600  Wednesday
# 3 2000-01-06  33.659954  34.845702  33.162705  34.329328  54976600   Thursday
# 4 2000-01-07  34.099846  34.348471  32.837597  33.239222  62013600     Friday
#
#   Status
# 0    red
# 1    red
# 2  green
# 3    red
# 4  green

# %% [markdown]
# #### Chart Donat

# %%
import matplotlib.pyplot as plt

# Contoh: df sudah punya kolom Status
# (kalau belum, bisa pakai kode sebelumnya untuk menambahkannya)

# Hitung jumlah masing-masing status
status_counts = df['Status'].value_counts()

# Warna donat
colors = {
    'green': '#2ecc71',   # hijau
    'red': '#e74c3c',     # merah
    'neutral': '#95a5a6'  # abu-abu
}

# Buat donut chart
fig, ax = plt.subplots(figsize=(6, 6))
wedges, texts, autotexts = ax.pie(
    status_counts,
    labels=status_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=[colors[k] for k in status_counts.index],
    wedgeprops=dict(width=0.4)  # buat efek donut
)

# Tambahkan teks di tengah
ax.text(0, 0, 'Status\nCandlestick', ha='center', va='center', fontsize=12, weight='bold')

plt.title('Distribusi Candle: Green, Red, dan Neutral', fontsize=14)
plt.show()

# %%
status_counts
# Out:
# Status
# green    3261
# red      3227
# Name: count, dtype: int64

# %% [markdown]
# #### LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#labeling
df['label_Day']            = le.fit_transform(df['Day'])
df.head()
# Out:
#         Date      Close       High        Low       Open    Volume        Day  \
# 0 2000-01-03  35.668076  36.299200  34.271952  35.916700  53228400     Monday
# 1 2000-01-04  34.463207  35.840206  34.348457  34.750082  54119000    Tuesday
# 2 2000-01-05  34.826591  35.610716  33.468718  34.004217  64059600  Wednesday
# 3 2000-01-06  33.659954  34.845702  33.162705  34.329328  54976600   Thursday
# 4 2000-01-07  34.099846  34.348471  32.837597  33.239222  62013600     Friday
#
#   Status  label_Day
# 0    red          1
# 1    red          3
# 2  green          4
# 3    red          2
# 4  green          0

# %% [markdown]
# #### Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib

# Contoh: buat dan fit scaler
scaler = MinMaxScaler()
cols = [
    'label_Day',
    'Close', 
    'High', 
    'Low',
    'Open',
    'Volume', 
]

# Dictionary untuk menyimpan hasil transformasi
scaled_data = {}

# Loop untuk setiap kolom
for col in cols:
    scaler = MinMaxScaler()
    df[[col]] = scaler.fit_transform(df[[col]])  # scaling per kolom
    joblib.dump(scaler, os.path.join(root_folder, f'scaler_{col}.pkl'))
    scaled_data[col] = scaler
    print(f"✅ Scaler for '{col}' saved as scaler_{col}.pkl")

print("\nAll individual scalers saved successfully!")
# Out:
# ✅ Scaler for 'label_Day' saved as scaler_label_Day.pkl
# ✅ Scaler for 'Close' saved as scaler_Close.pkl
# ✅ Scaler for 'High' saved as scaler_High.pkl
# ✅ Scaler for 'Low' saved as scaler_Low.pkl
# ✅ Scaler for 'Open' saved as scaler_Open.pkl
# ✅ Scaler for 'Volume' saved as scaler_Volume.pkl
#
# All individual scalers saved successfully!

# %%
df.head()
# Out:
#         Date     Close      High       Low      Open    Volume        Day  \
# 0 2000-01-03  0.046808  0.045658  0.044837  0.045515  0.078892     Monday
# 1 2000-01-04  0.044507  0.044812  0.044985  0.043367  0.080417    Tuesday
# 2 2000-01-05  0.045201  0.044390  0.043293  0.041994  0.097442  Wednesday
# 3 2000-01-06  0.042973  0.042981  0.042705  0.042593  0.081886   Thursday
# 4 2000-01-07  0.043813  0.042065  0.042079  0.040586  0.093938     Friday
#
#   Status  label_Day
# 0    red       0.25
# 1    red       0.75
# 2  green       1.00
# 3    red       0.50
# 4  green       0.00

# %% [markdown]
# #### Mapping label

# %%
import json
mapping_dicts = {}

cols = [
    'Day',
]

for col in cols:
    label_col = f"label_{col}"
    mapping_dicts[col] = dict(zip(df[col], df[label_col]))


with open(root_folder + 'label_mappings.json', 'w') as f:
    json.dump(mapping_dicts, f, indent=2)

rows = []
for col, mapping in mapping_dicts.items():
    for k, v in mapping.items():
        rows.append({'feature': col, 'original_value': k, 'label_value': v})

mapping_table = pd.DataFrame(rows)
print(mapping_table)
# Out:
#   feature original_value  label_value
# 0     Day         Monday         0.25
# 1     Day        Tuesday         0.75
# 2     Day      Wednesday         1.00
# 3     Day       Thursday         0.50
# 4     Day         Friday         0.00

# %% [markdown]
# #### Select Kolom To Trian

# %%
col_target = 'Status'
cols = [
    'Date',
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    'Volume',
    col_target
]
df = df[cols].copy()
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 2000-01-03       0.25  0.046808  0.045658  0.044837  0.045515  0.078892
# 1 2000-01-04       0.75  0.044507  0.044812  0.044985  0.043367  0.080417
# 2 2000-01-05       1.00  0.045201  0.044390  0.043293  0.041994  0.097442
# 3 2000-01-06       0.50  0.042973  0.042981  0.042705  0.042593  0.081886
# 4 2000-01-07       0.00  0.043813  0.042065  0.042079  0.040586  0.093938
#
#   Status
# 0    red
# 1    red
# 2  green
# 3    red
# 4  green

# %% [markdown]
# #### Tentukan target -> one-hot encoding

# %%
y_counts = df[col_target].value_counts(normalize=True)
labels = list(y_counts.index)

df_y_encoded = pd.get_dummies(df[col_target], prefix='y')

# Pastikan semua nama kolom lowercase dan spasi → underscore
df_y_encoded.columns = (
    df_y_encoded.columns.str.lower()
                        .str.replace(' ', '_')
)

# Gabungkan ke DataFrame utama
df = pd.concat([df.drop(col_target, axis=1), df_y_encoded.astype(int)], axis=1)
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 2000-01-03       0.25  0.046808  0.045658  0.044837  0.045515  0.078892
# 1 2000-01-04       0.75  0.044507  0.044812  0.044985  0.043367  0.080417
# 2 2000-01-05       1.00  0.045201  0.044390  0.043293  0.041994  0.097442
# 3 2000-01-06       0.50  0.042973  0.042981  0.042705  0.042593  0.081886
# 4 2000-01-07       0.00  0.043813  0.042065  0.042079  0.040586  0.093938
#
#    y_green  y_red
# 0        0      1
# 1        0      1
# 2        1      0
# 3        0      1
# 4        1      0

# %% [markdown]
# # Data Load To Train

# %% [markdown]
# #### select Future to traian

# %%
feature_cols = [
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    'Volume',
]
target_cols = [col for col in df.columns if col.startswith('y_')]

# %% [markdown]
# #### Split data

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

tgl_pembatas = '2022-01-01'
X_train = df[df['Date'] <= tgl_pembatas]
X_test  = df[df['Date'] > tgl_pembatas]
print(f'Train : f{X_train.shape}')
print(f'Test  : f{X_test.shape}')
# Out:
# Train : f(5536, 9)
# Test  : f(952, 9)

# %% [markdown]
# #### DataLoader

# %%
from data_set import MultiLabelTimeSeriesDataset
seq_length = 20
slide      = 1
# Buat dataset dengan class kamu
train_dataset = MultiLabelTimeSeriesDataset(X_train,seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)
test_dataset  = MultiLabelTimeSeriesDataset(X_test, seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)

# Buat DataLoader
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Cek contoh batch
for X, y in train_loader:
    print("X shape:", X.shape)
    print("y shape:", y.shape)
    print(X[:3])  # contoh fitur
    print(y[:3])  # contoh label
    break
# Out:
# X shape: torch.Size([32, 20, 6])
# y shape: torch.Size([32, 2])
# tensor([[[1.0000, 0.0458, 0.0440, 0.0463, 0.0446, 0.0193],
#          [0.5000, 0.0458, 0.0440, 0.0455, 0.0436, 0.0252],
#          [0.0000, 0.0465, 0.0442, 0.0462, 0.0441, 0.0290],
#          [0.2500, 0.0466, 0.0447, 0.0471, 0.0449, 0.0252],
#          [0.7500, 0.0471, 0.0448, 0.0471, 0.0451, 0.0370],
#          [1.0000, 0.0497, 0.0476, 0.0478, 0.0454, 0.0962],
#          [0.5000, 0.0504, 0.0498, 0.0507, 0.0500, 0.1285],
#          [0.0000, 0.0507, 0.0485, 0.0507, 0.0487, 0.0621],
#          [0.2500, 0.0509, 0.0489, 0.0506, 0.0486, 0.0521],
#          [0.7500, 0.0509, 0.0489, 0.0512, 0.0493, 0.0615],
#          [1.0000, 0.0510, 0.0494, 0.0513, 0.0500, 0.0774],
#          [0.5000, 0.0502, 0.0487, 0.0508, 0.0492, 0.0404],
#          [0.0000, 0.0504, 0.0482, 0.0508, 0.0482, 0.0335],
#          [0.2500, 0.0495, 0.0479, 0.0502, 0.0483, 0.0386],
#          [0.7500, 0.0494, 0.0473, 0.0497, 0.0476, 0.0353],
#          [1.0000, 0.0489, 0.0473, 0.0491, 0.0478, 0.0424],
#          [0.5000, 0.0482, 0.0467, 0.0488, 0.0467, 0.0417],
#          [0.0000, 0.0477, 0.0460, 0.0480, 0.0465, 0.0411],
#          [0.2500, 0.0485, 0.0463, 0.0484, 0.0461, 0.0464],
#          [0.7500, 0.0481, 0.0463, 0.0484, 0.0466, 0.0327]],
#
#         [[0.7500, 0.0109, 0.0102, 0.0112, 0.0105, 0.0719],
#          [1.0000, 0.0113, 0.0104, 0.0115, 0.0106, 0.0673],
#          [0.5000, 0.0112, 0.0105, 0.0116, 0.0107, 0.0616],
#          [0.0000, 0.0113, 0.0105, 0.0116, 0.0110, 0.0660],
#          [0.2500, 0.0112, 0.0105, 0.0117, 0.0108, 0.0509],
#          [0.7500, 0.0114, 0.0106, 0.0117, 0.0110, 0.0874],
#          [1.0000, 0.0115, 0.0107, 0.0119, 0.0111, 0.0638],
#          [0.5000, 0.0116, 0.0107, 0.0119, 0.0110, 0.0421],
#          [0.0000, 0.0115, 0.0105, 0.0117, 0.0110, 0.0395],
#          [0.2500, 0.0117, 0.0107, 0.0119, 0.0112, 0.0696],
#          [0.7500, 0.0119, 0.0109, 0.0121, 0.0113, 0.0716],
#          [1.0000, 0.0120, 0.0110, 0.0122, 0.0114, 0.0774],
#          [0.5000, 0.0120, 0.0110, 0.0124, 0.0115, 0.0660],
#          [0.0000, 0.0135, 0.0124, 0.0129, 0.0120, 0.2077],
#          [0.2500, 0.0139, 0.0128, 0.0137, 0.0128, 0.1391],
#          [0.7500, 0.0132, 0.0130, 0.0137, 0.0132, 0.1407],
#          [1.0000, 0.0133, 0.0126, 0.0136, 0.0127, 0.0642],
#          [0.5000, 0.0134, 0.0124, 0.0136, 0.0130, 0.0493],
#          [0.0000, 0.0136, 0.0126, 0.0138, 0.0128, 0.0444],
#          [0.2500, 0.0137, 0.0126, 0.0138, 0.0130, 0.0463]],
#
#         [[0.7500, 0.3733, 0.3631, 0.3733, 0.3626, 0.0275],
#          [1.0000, 0.3759, 0.3625, 0.3744, 0.3582, 0.0221],
#          [0.5000, 0.3698, 0.3638, 0.3722, 0.3615, 0.0382],
#          [0.0000, 0.3691, 0.3586, 0.3709, 0.3573, 0.0421],
#          [0.7500, 0.3761, 0.3629, 0.3720, 0.3577, 0.0399],
#          [1.0000, 0.3906, 0.3785, 0.3806, 0.3647, 0.0524],
#          [0.5000, 0.3917, 0.3794, 0.3901, 0.3771, 0.0403],
#          [0.0000, 0.3935, 0.3861, 0.3963, 0.3813, 0.0394],
#          [0.2500, 0.4001, 0.3856, 0.3934, 0.3849, 0.0445],
#          [0.7500, 0.4052, 0.3934, 0.4042, 0.3898, 0.0719],
#          [1.0000, 0.4063, 0.4045, 0.4043, 0.4006, 0.1074],
#          [0.5000, 0.4174, 0.4084, 0.4135, 0.3964, 0.0718],
#          [0.0000, 0.4046, 0.4002, 0.4066, 0.3971, 0.0605],
#          [0.2500, 0.4187, 0.4081, 0.4086, 0.3954, 0.0448],
#          [0.7500, 0.4184, 0.4078, 0.4201, 0.4065, 0.0321],
#          [1.0000, 0.4248, 0.4127, 0.4212, 0.4034, 0.0342],
#          [0.5000, 0.4230, 0.4094, 0.4233, 0.4089, 0.0311],
#          [0.0000, 0.4234, 0.4095, 0.4233, 0.4081, 0.0187],
#          [0.2500, 0.4239, 0.4102, 0.4241, 0.4098, 0.0258],
#          [0.7500, 0.4263, 0.4121, 0.4251, 0.4075, 0.0281]]])
# tensor([[0., 1.],
#         [1., 0.],
#         [1., 0.]])

# %% [markdown]
# # Config

# %%
from jcopdl.callback import Callback, set_config
config = set_config({
    "labels"         : labels,
    "threshold"      : 0.5,
    "input_size"     : len(test_dataset[0][0][0]),
    "hidden_size"    : 8,
    "num_layers"     : 1,
    "num_classes"    : len(labels),
    "dropout"        : 0.1,
    "bidirectional"  : True,
    "early_stop_patience" : 30,
    "col_target"     : col_target,
    "feature_cols"   : feature_cols
})
config
# Out:
# Config(bidirectional=True, col_target=Status, dropout=0.1, early_stop_patience=30, feature_cols=['label_Day', 'Close', 'High', 'Low', 'Open', 'Volume'], hidden_size=8, input_size=6, labels=['green', 'red'], num_classes=2, num_layers=1, threshold=0.5)

# %% [markdown]
# # MCOC

# %% [markdown]
# #### Model - Criterion - Optimizer - Callback

# %%
from class_lib import RNN_MultiLabelClassifier
from torch import optim, nn
from jcopdl.callback import Callback
import torch.optim as optim

#Model input_size, hidden_size, num_layers, num_classes, dropout=0.2, bidirectional=False
model = RNN_MultiLabelClassifier(
    input_size=config.input_size, 
    hidden_size=config.hidden_size, 
    num_layers=config.num_layers, 
    num_classes=config.num_classes, 
    dropout=config.dropout, 
    bidirectional=config.bidirectional
).to(device)

#Criterion
criterion =nn.BCELoss()

# --- Pilihan Optimizer ---
# AdamW
optimizer_adamw = optim.AdamW(model.parameters(), lr=0.001)
# Adam
optimizer_adam = optim.Adam(model.parameters(), lr=0.001)
# SGD (Stochastic Gradient Descent)
optimizer_sgd = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# RMSprop
optimizer_rmsprop = optim.RMSprop(model.parameters(), lr=0.001, momentum=0.9)
# Adagrad
optimizer_adagrad = optim.Adagrad(model.parameters(), lr=0.01)
# Adadelta
optimizer_adadelta = optim.Adadelta(model.parameters(), lr=0.1)
# ASGD (Averaged SGD)
optimizer_asgd = optim.ASGD(model.parameters(), lr=0.01)

# --- Contoh cara memilih salah satu ---
optim = optimizer_sgd  # misalnya kita pakai RAdam

#Callback
callback = Callback(model, config, outdir=root_folder,early_stop_patience=config.early_stop_patience)

# %% [markdown]
# # Training

# %%
from train_and_evaluate import train_and_evaluate_multi_label

train_and_evaluate_multi_label(
    model=model,
    train_dataset=train_dataset,
    test_dataset=test_dataset,
    train_loader=train_loader,
    test_loader=test_loader,
    criterion=criterion,
    optim=optim,
    config=config,
    device=device,
    labels=labels,          
    callback=callback
)
# Out:
# ─────────────────────────────────────────────────── 🚀 EPOCH 1 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 447.45it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 996.51it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6938 │ 0.6925 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4999 │ 0.4769 │ │ green │  0.5118  │
# │ Subset Accuracy  │ 0.0013 │ 0.3069 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.0025 │ 0.3915 │ └───────┴──────────┘
# │ Macro F1         │ 0.0025 │ 0.2785 │
# │ Overall Accuracy │ 0.5001 │ 0.5231 │
# └──────────────────┴────────┴────────┘
# Epoch     1
# Train_cost  = 0.6938 | Test_cost  = 0.6925 | Train_score = 0.5001 | Test_score = 0.5231 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 2 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 502.27it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1000.27it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6934 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4996 │ 0.4667 │ │ green │  0.5300  │
# │ Subset Accuracy  │ 0.0116 │ 0.5043 │ │  red  │  0.5365  │
# │ Micro F1         │ 0.0227 │ 0.5297 │ └───────┴──────────┘
# │ Macro F1         │ 0.0223 │ 0.3674 │
# │ Overall Accuracy │ 0.5004 │ 0.5333 │
# └──────────────────┴────────┴────────┘
# Epoch     2
# Train_cost  = 0.6934 | Test_cost  = 0.6924 | Train_score = 0.5004 | Test_score = 0.5333 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 3 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 473.84it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 999.58it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6923 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4966 │ 0.4673 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.0466 │ 0.4914 │ │  red  │  0.5311  │
# │ Micro F1         │ 0.0867 │ 0.5513 │ └───────┴──────────┘
# │ Macro F1         │ 0.0845 │ 0.4207 │
# │ Overall Accuracy │ 0.5034 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch     3
# Train_cost  = 0.6932 | Test_cost  = 0.6923 | Train_score = 0.5034 | Test_score = 0.5327 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 4 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 472.51it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 986.72it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4888 │ 0.4764 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.1371 │ 0.4045 │ │  red  │  0.5129  │
# │ Micro F1         │ 0.2239 │ 0.5743 │ └───────┴──────────┘
# │ Macro F1         │ 0.2239 │ 0.5022 │
# │ Overall Accuracy │ 0.5112 │ 0.5236 │
# └──────────────────┴────────┴────────┘
# Epoch     4
# Train_cost  = 0.6931 | Test_cost  = 0.6924 | Train_score = 0.5112 | Test_score = 0.5236 |
# ==> EarlyStop patience =  2 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 5 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 492.56it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 991.01it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4850 │ 0.4775 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2141 │ 0.3616 │ │  red  │  0.5107  │
# │ Micro F1         │ 0.3527 │ 0.5887 │ └───────┴──────────┘
# │ Macro F1         │ 0.3387 │ 0.5376 │
# │ Overall Accuracy │ 0.5150 │ 0.5225 │
# └──────────────────┴────────┴────────┘
# Epoch     5
# Train_cost  = 0.6930 | Test_cost  = 0.6924 | Train_score = 0.5150 | Test_score = 0.5225 |
# ==> EarlyStop patience =  3 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 6 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 496.09it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1197.46it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4864 │ 0.4780 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2529 │ 0.3487 │ │  red  │  0.5097  │
# │ Micro F1         │ 0.4059 │ 0.5926 │ └───────┴──────────┘
# │ Macro F1         │ 0.3803 │ 0.5464 │
# │ Overall Accuracy │ 0.5136 │ 0.5220 │
# └──────────────────┴────────┴────────┘
# Epoch     6
# Train_cost  = 0.6930 | Test_cost  = 0.6924 | Train_score = 0.5136 | Test_score = 0.5220 |
# ==> EarlyStop patience =  4 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 7 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 482.35it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 897.25it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4879 │ 0.4802 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2654 │ 0.3433 │ │  red  │  0.5054  │
# │ Micro F1         │ 0.4353 │ 0.5919 │ └───────┴──────────┘
# │ Macro F1         │ 0.4120 │ 0.5462 │
# │ Overall Accuracy │ 0.5121 │ 0.5198 │
# └──────────────────┴────────┴────────┘
# Epoch     7
# Train_cost  = 0.6930 | Test_cost  = 0.6924 | Train_score = 0.5121 | Test_score = 0.5198 |
# ==> EarlyStop patience =  5 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 8 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 481.66it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1165.45it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4899 │ 0.4791 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2435 │ 0.3541 │ │  red  │  0.5075  │
# │ Micro F1         │ 0.4503 │ 0.5894 │ └───────┴──────────┘
# │ Macro F1         │ 0.4358 │ 0.5402 │
# │ Overall Accuracy │ 0.5101 │ 0.5209 │
# └──────────────────┴────────┴────────┘
# Epoch     8
# Train_cost  = 0.6930 | Test_cost  = 0.6924 | Train_score = 0.5101 | Test_score = 0.5209 |
# ==> EarlyStop patience =  6 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 9 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 493.27it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 981.90it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4930 │ 0.4791 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2061 │ 0.3498 │ │  red  │  0.5075  │
# │ Micro F1         │ 0.4590 │ 0.5909 │ └───────┴──────────┘
# │ Macro F1         │ 0.4521 │ 0.5435 │
# │ Overall Accuracy │ 0.5070 │ 0.5209 │
# └──────────────────┴────────┴────────┘
# Epoch     9
# Train_cost  = 0.6930 | Test_cost  = 0.6924 | Train_score = 0.5070 | Test_score = 0.5209 |
# ==> EarlyStop patience =  7 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 10 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 488.43it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 977.44it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4882 │ 0.4769 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2870 │ 0.3981 │ │  red  │  0.5118  │
# │ Micro F1         │ 0.4891 │ 0.5761 │ └───────┴──────────┘
# │ Macro F1         │ 0.4697 │ 0.5072 │
# │ Overall Accuracy │ 0.5118 │ 0.5231 │
# └──────────────────┴────────┴────────┘
# Epoch    10
# Train_cost  = 0.6930 | Test_cost  = 0.6924 | Train_score = 0.5118 | Test_score = 0.5231 |
# ==> EarlyStop patience =  8 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 11 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 502.42it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1010.84it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6923 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4973 │ 0.4775 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.1356 │ 0.4045 │ │  red  │  0.5107  │
# │ Micro F1         │ 0.4619 │ 0.5729 │ └───────┴──────────┘
# │ Macro F1         │ 0.4620 │ 0.4996 │
# │ Overall Accuracy │ 0.5027 │ 0.5225 │
# └──────────────────┴────────┴────────┘
# Epoch    11
# Train_cost  = 0.6930 | Test_cost  = 0.6923 | Train_score = 0.5027 | Test_score = 0.5225 |
# ==> EarlyStop patience =  9 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 12 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 438.61it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1035.95it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4908 │ 0.4828 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2322 │ 0.3584 │ │  red  │  0.5000  │
# │ Micro F1         │ 0.4890 │ 0.5833 │ └───────┴──────────┘
# │ Macro F1         │ 0.4817 │ 0.5291 │
# │ Overall Accuracy │ 0.5092 │ 0.5172 │
# └──────────────────┴────────┴────────┘
# Epoch    12
# Train_cost  = 0.6930 | Test_cost  = 0.6924 | Train_score = 0.5092 | Test_score = 0.5172 |
# ==> EarlyStop patience = 10 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 13 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 505.00it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1183.42it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6923 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4863 │ 0.4780 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3296 │ 0.4034 │ │  red  │  0.5097  │
# │ Micro F1         │ 0.4981 │ 0.5727 │ └───────┴──────────┘
# │ Macro F1         │ 0.4722 │ 0.4994 │
# │ Overall Accuracy │ 0.5137 │ 0.5220 │
# └──────────────────┴────────┴────────┘
# Epoch    13
# Train_cost  = 0.6929 | Test_cost  = 0.6923 | Train_score = 0.5137 | Test_score = 0.5220 |
# ==> EarlyStop patience = 11 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 14 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 474.35it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1183.52it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4863 │ 0.4791 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3310 │ 0.4002 │ │  red  │  0.5075  │
# │ Micro F1         │ 0.4977 │ 0.5725 │ └───────┴──────────┘
# │ Macro F1         │ 0.4725 │ 0.5000 │
# │ Overall Accuracy │ 0.5137 │ 0.5209 │
# └──────────────────┴────────┴────────┘
# Epoch    14
# Train_cost  = 0.6929 | Test_cost  = 0.6924 | Train_score = 0.5137 | Test_score = 0.5209 |
# ==> EarlyStop patience = 12 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 15 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 509.01it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 990.05it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6923 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4858 │ 0.4732 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3254 │ 0.4174 │ │  red  │  0.5193  │
# │ Micro F1         │ 0.5025 │ 0.5735 │ └───────┴──────────┘
# │ Macro F1         │ 0.4791 │ 0.4972 │
# │ Overall Accuracy │ 0.5142 │ 0.5268 │
# └──────────────────┴────────┴────────┘
# Epoch    15
# Train_cost  = 0.6929 | Test_cost  = 0.6923 | Train_score = 0.5142 | Test_score = 0.5268 |
# ==> EarlyStop patience = 13 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 16 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 499.39it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 943.58it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6923 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4829 │ 0.4721 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3546 │ 0.4206 │ │  red  │  0.5215  │
# │ Micro F1         │ 0.4987 │ 0.5736 │ └───────┴──────────┘
# │ Macro F1         │ 0.4682 │ 0.4965 │
# │ Overall Accuracy │ 0.5171 │ 0.5279 │
# └──────────────────┴────────┴────────┘
# Epoch    16
# Train_cost  = 0.6929 | Test_cost  = 0.6923 | Train_score = 0.5171 | Test_score = 0.5279 |
# ==> EarlyStop patience = 14 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 17 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 442.53it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1045.94it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6923 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4865 │ 0.4678 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3318 │ 0.4689 │ │  red  │  0.5300  │
# │ Micro F1         │ 0.4952 │ 0.5600 │ └───────┴──────────┘
# │ Macro F1         │ 0.4706 │ 0.4515 │
# │ Overall Accuracy │ 0.5135 │ 0.5322 │
# └──────────────────┴────────┴────────┘
# Epoch    17
# Train_cost  = 0.6929 | Test_cost  = 0.6923 | Train_score = 0.5135 | Test_score = 0.5322 |
# ==> EarlyStop patience = 15 | Best test_score: 0.5333
# ─────────────────────────────────────────────────── 🚀 EPOCH 18 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 501.20it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1181.13it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4872 │ 0.4662 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2906 │ 0.5086 │ │  red  │  0.5333  │
# │ Micro F1         │ 0.4891 │ 0.5453 │ └───────┴──────────┘
# │ Macro F1         │ 0.4754 │ 0.3961 │
# │ Overall Accuracy │ 0.5128 │ 0.5338 │
# └──────────────────┴────────┴────────┘
# Epoch    18
# Train_cost  = 0.6929 | Test_cost  = 0.6922 | Train_score = 0.5128 | Test_score = 0.5338 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 19 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 456.47it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 878.31it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4861 │ 0.4694 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.2707 │ 0.4732 │ │  red  │  0.5268  │
# │ Micro F1         │ 0.4935 │ 0.5561 │ └───────┴──────────┘
# │ Macro F1         │ 0.4848 │ 0.4407 │
# │ Overall Accuracy │ 0.5139 │ 0.5306 │
# └──────────────────┴────────┴────────┘
# Epoch    19
# Train_cost  = 0.6929 | Test_cost  = 0.6922 | Train_score = 0.5139 | Test_score = 0.5306 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5338
# ─────────────────────────────────────────────────── 🚀 EPOCH 20 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 500.59it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1150.50it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4890 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3345 │ 0.5021 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4875 │ 0.5489 │ └───────┴──────────┘
# │ Macro F1         │ 0.4628 │ 0.4090 │
# │ Overall Accuracy │ 0.5110 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    20
# Train_cost  = 0.6929 | Test_cost  = 0.6922 | Train_score = 0.5110 | Test_score = 0.5343 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 21 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 505.64it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1165.83it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6923 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4839 │ 0.4694 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3191 │ 0.4689 │ │  red  │  0.5268  │
# │ Micro F1         │ 0.4910 │ 0.5579 │ └───────┴──────────┘
# │ Macro F1         │ 0.4723 │ 0.4466 │
# │ Overall Accuracy │ 0.5161 │ 0.5306 │
# └──────────────────┴────────┴────────┘
# Epoch    21
# Train_cost  = 0.6929 | Test_cost  = 0.6923 | Train_score = 0.5161 | Test_score = 0.5306 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5343
# ─────────────────────────────────────────────────── 🚀 EPOCH 22 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 454.91it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 944.17it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4843 │ 0.4646 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3644 │ 0.5075 │ │  red  │  0.5365  │
# │ Micro F1         │ 0.4906 │ 0.5480 │ └───────┴──────────┘
# │ Macro F1         │ 0.4584 │ 0.4038 │
# │ Overall Accuracy │ 0.5157 │ 0.5354 │
# └──────────────────┴────────┴────────┘
# Epoch    22
# Train_cost  = 0.6929 | Test_cost  = 0.6922 | Train_score = 0.5157 | Test_score = 0.5354 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 23 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 498.39it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 886.21it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4836 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3474 │ 0.5225 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4874 │ 0.5398 │ └───────┴──────────┘
# │ Macro F1         │ 0.4654 │ 0.3724 │
# │ Overall Accuracy │ 0.5164 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    23
# Train_cost  = 0.6929 | Test_cost  = 0.6922 | Train_score = 0.5164 | Test_score = 0.5343 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 24 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 483.29it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1178.41it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4825 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3379 │ 0.5021 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4872 │ 0.5489 │ └───────┴──────────┘
# │ Macro F1         │ 0.4674 │ 0.4090 │
# │ Overall Accuracy │ 0.5175 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    24
# Train_cost  = 0.6929 | Test_cost  = 0.6922 | Train_score = 0.5175 | Test_score = 0.5343 |
# ==> EarlyStop patience =  2 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 25 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 444.12it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1012.03it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4844 │ 0.4646 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3842 │ 0.5097 │ │  red  │  0.5365  │
# │ Micro F1         │ 0.4920 │ 0.5471 │ └───────┴──────────┘
# │ Macro F1         │ 0.4530 │ 0.4001 │
# │ Overall Accuracy │ 0.5156 │ 0.5354 │
# └──────────────────┴────────┴────────┘
# Epoch    25
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5156 | Test_score = 0.5354 |
# ==> EarlyStop patience =  3 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 26 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 487.53it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 943.49it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4811 │ 0.4673 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3740 │ 0.5290 │ │  red  │  0.5311  │
# │ Micro F1         │ 0.4903 │ 0.5345 │ └───────┴──────────┘
# │ Macro F1         │ 0.4604 │ 0.3528 │
# │ Overall Accuracy │ 0.5189 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch    26
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5189 | Test_score = 0.5327 |
# ==> EarlyStop patience =  4 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 27 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 478.58it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 996.43it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4819 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3745 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.4881 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4582 │ 0.3506 │
# │ Overall Accuracy │ 0.5181 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    27
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5181 | Test_score = 0.5349 |
# ==> EarlyStop patience =  5 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 28 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 456.50it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1033.72it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4806 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3450 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.4818 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4642 │ 0.3506 │
# │ Overall Accuracy │ 0.5194 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    28
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5194 | Test_score = 0.5349 |
# ==> EarlyStop patience =  6 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 29 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 497.91it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1037.71it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4812 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3689 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.4839 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4585 │ 0.3506 │
# │ Overall Accuracy │ 0.5188 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    29
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5188 | Test_score = 0.5349 |
# ==> EarlyStop patience =  7 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 30 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 455.86it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 998.52it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4838 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.4193 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.5018 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4542 │ 0.3506 │
# │ Overall Accuracy │ 0.5162 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    30
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5162 | Test_score = 0.5349 |
# ==> EarlyStop patience =  8 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 31 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 493.93it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 853.21it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4831 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3785 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4834 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4552 │ 0.3483 │
# │ Overall Accuracy │ 0.5169 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    31
# Train_cost  = 0.6928 | Test_cost  = 0.6921 | Train_score = 0.5169 | Test_score = 0.5343 |
# ==> EarlyStop patience =  9 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 32 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 496.86it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 929.37it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4825 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3591 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.4764 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4562 │ 0.3506 │
# │ Overall Accuracy │ 0.5175 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    32
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5175 | Test_score = 0.5349 |
# ==> EarlyStop patience = 10 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 33 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 448.51it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 928.82it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4796 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3727 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.4807 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4567 │ 0.3506 │
# │ Overall Accuracy │ 0.5204 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    33
# Train_cost  = 0.6928 | Test_cost  = 0.6921 | Train_score = 0.5204 | Test_score = 0.5349 |
# ==> EarlyStop patience = 11 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 34 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 492.95it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 950.64it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4815 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3660 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.4769 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4560 │ 0.3506 │
# │ Overall Accuracy │ 0.5185 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    34
# Train_cost  = 0.6928 | Test_cost  = 0.6921 | Train_score = 0.5185 | Test_score = 0.5349 |
# ==> EarlyStop patience = 12 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 35 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 365.78it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1101.82it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6928 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4801 │ 0.4651 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.4003 │ 0.5343 │ │  red  │  0.5354  │
# │ Micro F1         │ 0.4888 │ 0.5351 │ └───────┴──────────┘
# │ Macro F1         │ 0.4526 │ 0.3506 │
# │ Overall Accuracy │ 0.5199 │ 0.5349 │
# └──────────────────┴────────┴────────┘
# Epoch    35
# Train_cost  = 0.6928 | Test_cost  = 0.6922 | Train_score = 0.5199 | Test_score = 0.5349 |
# ==> EarlyStop patience = 13 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 36 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 444.78it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 989.28it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4808 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3988 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4870 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4527 │ 0.3483 │
# │ Overall Accuracy │ 0.5192 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    36
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5192 | Test_score = 0.5343 |
# ==> EarlyStop patience = 14 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 37 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 489.57it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 970.71it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4801 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3910 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4828 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4530 │ 0.3483 │
# │ Overall Accuracy │ 0.5199 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    37
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5199 | Test_score = 0.5343 |
# ==> EarlyStop patience = 15 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 38 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 468.82it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1021.93it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4800 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3936 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4829 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4523 │ 0.3483 │
# │ Overall Accuracy │ 0.5200 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    38
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5200 | Test_score = 0.5343 |
# ==> EarlyStop patience = 16 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 39 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 494.90it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 954.61it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4838 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3722 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4717 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4505 │ 0.3483 │
# │ Overall Accuracy │ 0.5162 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    39
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5162 | Test_score = 0.5343 |
# ==> EarlyStop patience = 17 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 40 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 493.12it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 999.99it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4836 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.4046 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4846 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4500 │ 0.3483 │
# │ Overall Accuracy │ 0.5164 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    40
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5164 | Test_score = 0.5343 |
# ==> EarlyStop patience = 18 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 41 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 508.69it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1145.84it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4801 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3874 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4787 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4521 │ 0.3483 │
# │ Overall Accuracy │ 0.5199 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    41
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5199 | Test_score = 0.5343 |
# ==> EarlyStop patience = 19 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 42 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 491.19it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 945.71it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4796 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3932 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4797 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4517 │ 0.3483 │
# │ Overall Accuracy │ 0.5204 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    42
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5204 | Test_score = 0.5343 |
# ==> EarlyStop patience = 20 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 43 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 512.61it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1178.69it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4813 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.4104 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4862 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4505 │ 0.3483 │
# │ Overall Accuracy │ 0.5187 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    43
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5187 | Test_score = 0.5343 |
# ==> EarlyStop patience = 21 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 44 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 471.50it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1013.82it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4821 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3916 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4759 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4482 │ 0.3483 │
# │ Overall Accuracy │ 0.5179 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    44
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5179 | Test_score = 0.5343 |
# ==> EarlyStop patience = 22 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 45 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 490.64it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 885.89it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4820 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3867 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4738 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4500 │ 0.3483 │
# │ Overall Accuracy │ 0.5180 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    45
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5180 | Test_score = 0.5343 |
# ==> EarlyStop patience = 23 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 46 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 479.59it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1009.78it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4808 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3738 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4690 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4491 │ 0.3483 │
# │ Overall Accuracy │ 0.5192 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    46
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5192 | Test_score = 0.5343 |
# ==> EarlyStop patience = 24 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 47 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 508.82it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1159.42it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4811 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3871 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4729 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4507 │ 0.3483 │
# │ Overall Accuracy │ 0.5189 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    47
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5189 | Test_score = 0.5343 |
# ==> EarlyStop patience = 25 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 48 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 467.31it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 910.77it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4833 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.4262 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4904 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4498 │ 0.3483 │
# │ Overall Accuracy │ 0.5167 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    48
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5167 | Test_score = 0.5343 |
# ==> EarlyStop patience = 26 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 49 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 495.70it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 861.71it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6927 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4827 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.4090 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4810 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4485 │ 0.3483 │
# │ Overall Accuracy │ 0.5173 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    49
# Train_cost  = 0.6927 | Test_cost  = 0.6921 | Train_score = 0.5173 | Test_score = 0.5343 |
# ==> EarlyStop patience = 27 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 50 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 485.23it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1157.19it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6926 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4817 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3869 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4710 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4495 │ 0.3483 │
# │ Overall Accuracy │ 0.5183 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    50
# Train_cost  = 0.6926 | Test_cost  = 0.6922 | Train_score = 0.5183 | Test_score = 0.5343 |
# ==> EarlyStop patience = 28 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 51 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 454.67it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1046.44it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6926 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4825 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3959 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4733 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4479 │ 0.3483 │
# │ Overall Accuracy │ 0.5175 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    51
# Train_cost  = 0.6926 | Test_cost  = 0.6922 | Train_score = 0.5175 | Test_score = 0.5343 |
# ==> EarlyStop patience = 29 | Best test_score: 0.5354
# ─────────────────────────────────────────────────── 🚀 EPOCH 52 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 491.16it/s]
# test: 100%|██████████| 30/30 [00:00<00:00, 1001.64it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6926 │ 0.6922 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4829 │ 0.4657 │ │ green │  0.5343  │
# │ Subset Accuracy  │ 0.3939 │ 0.5343 │ │  red  │  0.5343  │
# │ Micro F1         │ 0.4718 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.4467 │ 0.3483 │
# │ Overall Accuracy │ 0.5171 │ 0.5343 │
# └──────────────────┴────────┴────────┘
# Epoch    52
# Train_cost  = 0.6926 | Test_cost  = 0.6922 | Train_score = 0.5171 | Test_score = 0.5343 |
# ==> EarlyStop patience = 30 | Best test_score: 0.5354
# ==> Execute Early Stopping at epoch: 52 | Best test_score: 0.5354
# ==> Best model is saved at timeseris/multi-label-clasification/rnn/microsoft_stock_data/
# ⏹️ Training dihentikan oleh early stopping.

# %% [markdown]
# # Evaluate

# %%
from evaluate import evaluate_multi_label

hsl = evaluate_multi_label(model, test_loader, target_cols,criterion, device, config.threshold)
# Out:
#        📊 Evaluasi Model         🎯 Per-Label Accuracy
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━┳━━━━━━━━━┓
# ┃ Metrik              ┃  Nilai ┃ ┃  Label  ┃ Akurasi ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━╇━━━━━━━━━┩
# │ 🔹 Overall Accuracy │ 0.5354 │ │ y_green │ 0.5343  │
# │ ✅ Subset  Accuracy │ 0.5075 │ │  y_red  │ 0.5365  │
# │ 💥 Loss (avg)       │ 0.6922 │ └─────────┴─────────┘
# │ 📉 Hamming Loss     │ 0.4646 │
# │ ⚖️  Micro F1-score   │ 0.5480 │
# │ 📈 Macro F1-score   │ 0.4038 │
# └─────────────────────┴────────┘

# %%
hsl = hsl['df']
hsl = hsl[hsl['Benar (%)'] == 100]
hsl.head(300)
# Out:
#          Target    Prediksi  Benar (%)
# 0    [1.0, 0.0]  [1.0, 0.0]      100.0
# 2    [1.0, 0.0]  [1.0, 0.0]      100.0
# 6    [1.0, 0.0]  [1.0, 0.0]      100.0
# 7    [1.0, 0.0]  [1.0, 0.0]      100.0
# 10   [1.0, 0.0]  [1.0, 0.0]      100.0
# ..          ...         ...        ...
# 588  [1.0, 0.0]  [1.0, 0.0]      100.0
# 589  [1.0, 0.0]  [1.0, 0.0]      100.0
# 590  [1.0, 0.0]  [1.0, 0.0]      100.0
# 592  [1.0, 0.0]  [1.0, 0.0]      100.0
# 593  [1.0, 0.0]  [1.0, 0.0]      100.0
#
# [300 rows x 3 columns]
