# %%
import pandas as pd

# %%
# Baca file CSV
df = pd.read_csv("data_news/news.csv")

# Ubah kolom 'tgl' ke datetime
df['tgl'] = pd.to_datetime(df['tgl'])
df = df.sort_values(by='tgl', ascending=True)
#df['tgl'] = df['tgl'].dt.tz_localize('Asia/Jakarta')
df = df[df['tgl'] >= '2020-01-04']

df['tgl_only'] = df['tgl'].dt.date
df['jam_only'] = df['tgl'].dt.time

# %%
df
# Out:
#                       tgl                                              judul  \
# 183   2020-01-24 08:00:00        ARNA Siapkan Rp30 Miliar Beli Kembali Saham
# 184   2020-02-12 08:00:00  Usai Dicaplok Grup Siam Cement, Laba Fajar Pap...
# 185   2020-02-12 08:00:00       Kinerja Keuangan Fajar Paper 2019 Terkoreksi
# 186   2020-02-20 08:00:00  Fajar Surya Wisesa (FASW) catatkan penurunan p...
# 187   2020-02-20 08:00:00  Raih Doktor di ITS dengan Kembangkan Sistem Es...
# ...                   ...                                                ...
# 16600 2025-11-05 02:02:00  Percepat Realisasi Manfaat Ekonomi Sektor Miga...
# 16601 2025-11-05 02:03:00  Bogor Buka Pendaftaran Calendar of Event 2026:...
# 16602 2025-11-05 02:03:00  Roti Kinasih: Lebih dari Sekadar Roti, Simbol ...
# 16603 2025-11-05 02:07:00  Tema Hari Kesehatan Nasional 2025: Generasi Se...
# 16604 2025-11-05 02:11:00       Rekomendasi Saham Hari Ini: ACES hingga EXCL
#
# ...

# %%
print(df.dtypes)
# Out:
# tgl            datetime64[ns]
# judul                  object
# rss                    object
# nama_sumber            object
# link_sumber            object
# query                  object
# link_berita            object
# konten                float64
# ringkasan             float64
# tgl_only               object
# jam_only               object
# dtype: object

# %%
news = df[['tgl_only', 'jam_only','nama_sumber', 'judul']].copy()
news
# Out:
#          tgl_only  jam_only      nama_sumber  \
# 183    2020-01-24  08:00:00        Pasardana
# 184    2020-02-12  08:00:00   CNBC Indonesia
# 185    2020-02-12  08:00:00      investor.id
# 186    2020-02-20  08:00:00     kontan.co.id
# 187    2020-02-20  08:00:00        its.ac.id
# ...           ...       ...              ...
# 16600  2025-11-05  02:02:00      Sinar Jambi
# 16601  2025-11-05  02:03:00      Pojok Bogor
# 16602  2025-11-05  02:03:00     Target Hukum
# 16603  2025-11-05  02:07:00       Radar Solo
# 16604  2025-11-05  02:11:00  MetroTVNews.com
#
#                                                    judul
# 183          ARNA Siapkan Rp30 Miliar Beli Kembali Saham
# 184    Usai Dicaplok Grup Siam Cement, Laba Fajar Pap...
# 185         Kinerja Keuangan Fajar Paper 2019 Terkoreksi
# 186    Fajar Surya Wisesa (FASW) catatkan penurunan p...
# 187    Raih Doktor di ITS dengan Kembangkan Sistem Es...
# ...                                                  ...
# ...

# %% [markdown]
# # Ambil tanggal unik
# unique_dates = news['tgl_only'].unique()
# unique_dates_str = [str(t) for t in unique_dates]
# print(len(unique_dates_str))
# print(unique_dates_str[:100])

# %%
news
# Out:
#          tgl_only  jam_only      nama_sumber  \
# 183    2020-01-24  08:00:00        Pasardana
# 184    2020-02-12  08:00:00   CNBC Indonesia
# 185    2020-02-12  08:00:00      investor.id
# 186    2020-02-20  08:00:00     kontan.co.id
# 187    2020-02-20  08:00:00        its.ac.id
# ...           ...       ...              ...
# 16600  2025-11-05  02:02:00      Sinar Jambi
# 16601  2025-11-05  02:03:00      Pojok Bogor
# 16602  2025-11-05  02:03:00     Target Hukum
# 16603  2025-11-05  02:07:00       Radar Solo
# 16604  2025-11-05  02:11:00  MetroTVNews.com
#
#                                                    judul
# 183          ARNA Siapkan Rp30 Miliar Beli Kembali Saham
# 184    Usai Dicaplok Grup Siam Cement, Laba Fajar Pap...
# 185         Kinerja Keuangan Fajar Paper 2019 Terkoreksi
# 186    Fajar Surya Wisesa (FASW) catatkan penurunan p...
# 187    Raih Doktor di ITS dengan Kembangkan Sistem Es...
# ...                                                  ...
# ...

# %%
stock = pd.read_csv("data_news/ihsg.csv")
stock['Date'] = pd.to_datetime(stock['Date'])
stock = stock.sort_values(by='Date', ascending=True)
stock["Perubahan%"] = (
    stock["Perubahan%"]
    .str.replace("%", "", regex=False)   # hilangkan tanda persen
    .str.replace(",", ".", regex=False)  # ubah koma jadi titik
    .astype(float)                       # ubah ke tipe float
)
# Tambahkan kolom 'Status' berdasarkan nilai
def get_status(x):
    if x < 0:
        return "bad"
    elif x == 0:
        return "netral"
    else:
        return "good"

stock["Status"] = stock["Perubahan%"].apply(get_status)
stock
# Out:
# /tmp/ipykernel_30271/359980782.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   stock['Date'] = pd.to_datetime(stock['Date'])
#            Date     Close      Open      High       Low  Volume  Perubahan%  \
# 1349 2020-01-04  4.466,04  4.538,93  4.627,42  4.445,14   4,18B       -1.61
# 1291 2020-01-07  4.914,39  4.905,39  4.928,61  4.885,60   4,32B        0.18
# 1251 2020-01-09  5.310,68  5.238,49  5.310,68  5.219,21   9,05B        1.38
# 1229 2020-01-10  4.970,09  4.899,64  4.970,09  4.899,00   9,64B        2.05
# 1189 2020-01-12  5.724,74  5.637,89  5.736,32  5.594,28  20,95B        2.00
# ...         ...       ...       ...       ...       ...     ...         ...
# 173  2025-12-02  6.645,78  6.540,95  6.645,78  6.537,48  14,13B        1.74
# 153  2025-12-03  6.665,04  6.566,80  6.665,04  6.566,20  13,97B        1.82
# ...

# %%
import pandas as pd
from datetime import timedelta

def get_daily_data_no_merged(date_str: str, news: pd.DataFrame, stock: pd.DataFrame):
    cutoff = pd.to_datetime("15:00:00").time()
    
    news['tgl_only'] = pd.to_datetime(news['tgl_only'])
    news_filtered = news[(news['tgl_only'] == date_str) & (news['jam_only'] <= cutoff)]

    stock['Date']    = pd.to_datetime(stock['Date'])
    stock_filtered = stock[stock['Date'] == date_str]

    return news_filtered, stock_filtered

# %%
berita, saham = get_daily_data_no_merged("2020-02-20", news, stock)
berita
# Out:
#       tgl_only  jam_only   nama_sumber  \
# 186 2020-02-20  08:00:00  kontan.co.id
# 187 2020-02-20  08:00:00     its.ac.id
#
#                                                  judul
# 186  Fajar Surya Wisesa (FASW) catatkan penurunan p...
# 187  Raih Doktor di ITS dengan Kembangkan Sistem Es...

# %%
saham
# Out:
#            Date     Close      Open      High       Low Volume  Perubahan%  \
# 1377 2020-02-20  5.942,49  5.941,45  5.960,71  5.929,15  3,74B        0.23
#
#      Status
# 1377   good

# %%
import pandas as pd
from datetime import timedelta

# Contoh: news dan stock sudah dibaca sebelumnya
# news = pd.read_csv("news.csv")
# stock = pd.read_csv("stock.csv")

# Pastikan format datetime benar
news['tgl_only'] = pd.to_datetime(news['tgl_only'])
stock['Date'] = pd.to_datetime(stock['Date'])

# Jika jam masih string, ubah jadi time
news['jam_only'] = pd.to_datetime(news['jam_only'], format='%H:%M:%S').dt.time

# Tentukan cutoff jam perdagangan (15:00)
cutoff = pd.to_datetime("15:00:00").time()

# Buat kolom acuan join (tgl_join)
def find_stock_date(row):
    if row['jam_only'] > cutoff:
        # berita di atas jam 15:00 → pakai hari berikutnya
        next_day = row['tgl_only'] + timedelta(days=1)
        return next_day
    else:
        # berita di bawah jam 15:00 → pakai hari yang sama
        return row['tgl_only']

news['tgl_join'] = news.apply(find_stock_date, axis=1)

# Gabungkan berdasarkan tanggal acuan
merged = pd.merge(
    news,
    stock[['Date', 'Perubahan%', 'Status']],
    left_on='tgl_join',
    right_on='Date',
    how='left'
)

# Hapus kolom tambahan
merged = merged.drop(columns=['Date'])

# Opsional: isi NaN jadi 'unknown'
#merged['Status'] = merged['Status'].fillna('unknown')
merged = merged.dropna(subset=['Status'])

merged[['tgl_only', 'jam_only','tgl_join', 'judul',  'Status']]
# Out:
#         tgl_only  jam_only   tgl_join  \
# 0     2020-01-24  08:00:00 2020-01-24
# 1     2020-02-12  08:00:00 2020-02-12
# 2     2020-02-12  08:00:00 2020-02-12
# 3     2020-02-20  08:00:00 2020-02-20
# 4     2020-02-20  08:00:00 2020-02-20
# ...          ...       ...        ...
# 16049 2025-11-04  14:53:00 2025-11-04
# 16050 2025-11-04  14:56:00 2025-11-04
# 16051 2025-11-04  14:58:00 2025-11-04
# 16052 2025-11-04  14:59:00 2025-11-04
# 16053 2025-11-04  15:00:00 2025-11-04
#
#                                                    judul Status
# 0            ARNA Siapkan Rp30 Miliar Beli Kembali Saham    bad
# 1      Usai Dicaplok Grup Siam Cement, Laba Fajar Pap...   good
# 2           Kinerja Keuangan Fajar Paper 2019 Terkoreksi   good
# 3      Fajar Surya Wisesa (FASW) catatkan penurunan p...   good
# 4      Raih Doktor di ITS dengan Kembangkan Sistem Es...   good
# ...                                                  ...    ...
# ...

# %%
import matplotlib.pyplot as plt

# Hitung jumlah tiap kategori status
status_counts = merged['Status'].value_counts()

# Buat diagram donat
fig, ax = plt.subplots(figsize=(6, 6))
wedges, texts, autotexts = ax.pie(
    status_counts,
    labels=status_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops=dict(width=0.4)  # Membuat donat (lubang di tengah)
)

# Tambahkan lingkaran putih di tengah
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# Judul
plt.title('Distribusi Status Berita (Good / Neutral / Bad)', fontsize=14)

# Tampilkan grafik
plt.show()

# %%
from transformers import AutoTokenizer, AutoModel
import torch

bert_model = "indobenchmark/indobert-lite-base-p1"

tokenizer = AutoTokenizer.from_pretrained(bert_model)
model = AutoModel.from_pretrained(bert_model)

kalimat = "Anak-anak bermain di taman kota."
inputs = tokenizer(kalimat, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)

print("✅ IndoBERT berhasil dimuat!")
print("Embedding shape:", outputs.last_hidden_state.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       2 import torch
#       4 bert_model = "indobenchmark/indobert-lite-base-p1"
# ----> 6 tokenizer = AutoTokenizer.from_pretrained(bert_model)
#       7 model = AutoModel.from_pretrained(bert_model)
#       9 kalimat = "Anak-anak bermain di taman kota."
#
# File ~/miniconda3/envs/ai/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:1159, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1156 tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#    1158 if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# -> 1159     return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1160 else:
#    1161     if tokenizer_class_py is not None:
#
# ...

# %%
# !pip uninstall transformers sentencepiece -y
# Out:
# Found existing installation: transformers 4.57.1
# Uninstalling transformers-4.57.1:
#   Successfully uninstalled transformers-4.57.1
# Found existing installation: sentencepiece 0.2.1
# Uninstalling sentencepiece-0.2.1:
#   Successfully uninstalled sentencepiece-0.2.1

# %%
# !pip install transformers==4.36.2 sentencepiece==0.1.99
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 26.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.7 MB/s  0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [transformers] [transformers]
# ...
