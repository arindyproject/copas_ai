# %% [markdown]
# #                                  timeseris Multi Label Clasification - GRU

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import os
import numpy as np

# %%
file_name = "microsoft_stock_data"
root_folder = f'timeseris/multi-label-clasification/rnn/{file_name}/' 
os.makedirs(root_folder, exist_ok=True)

df = pd.read_csv('sample_data/'+file_name+'.csv')

df.head()
# Out:
#         Date     Close      High       Low      Open    Volume
# 0  3/26/1986  0.057906  0.058437  0.055781  0.056312  22752000
# 1  3/27/1986  0.058969  0.058969  0.057906  0.057906  16848000
# 2  3/31/1986  0.058437  0.058969  0.057375  0.058969  12873600
# 3   4/1/1986  0.057906  0.058437  0.057906  0.058437  11088000
# 4   4/2/1986  0.058437  0.059500  0.057906  0.057906  27014400

# %% [markdown]
# #### Pilih tahun mulai data

# %%
# Pastikan kolom Date dalam format datetime
df['Date'] = pd.to_datetime(df['Date'])

# Filter data mulai dari tahun 2000
df = df[df['Date'] >= '1995-01-01']

# (Opsional) urutkan berdasarkan tanggal
df = df.sort_values('Date').reset_index(drop=True)
df.head()
# Out:
#         Date     Close      High       Low      Open    Volume
# 0 1995-01-03  2.302169  2.352372  2.299778  2.352372  39545600
# 1 1995-01-04  2.318903  2.323684  2.275872  2.304559  51611200
# 2 1995-01-05  2.280653  2.333246  2.271091  2.328465  39824000
# 3 1995-01-06  2.318903  2.342809  2.285434  2.290216  46681600
# 4 1995-01-09  2.304561  2.333248  2.285436  2.328467  46000000

# %% [markdown]
# #### tambahkan status green, red, dan netral || DayName

# %%
# === Tambahkan kolom nama hari ===
df['Day'] =  df['Date'].dt.day_name()  # bahasa Inggris

# Buat kondisi
conditions = [
    df['Close'] > df['Open'],
    df['Close'] < df['Open'],
    df['Close'] == df['Open']
]
choices = ['green', 'red', 'red']

df['Status'] = np.select(conditions, choices)
df.head()
# Out:
#         Date     Close      High       Low      Open    Volume        Day  \
# 0 1995-01-03  2.302169  2.352372  2.299778  2.352372  39545600    Tuesday
# 1 1995-01-04  2.318903  2.323684  2.275872  2.304559  51611200  Wednesday
# 2 1995-01-05  2.280653  2.333246  2.271091  2.328465  39824000   Thursday
# 3 1995-01-06  2.318903  2.342809  2.285434  2.290216  46681600     Friday
# 4 1995-01-09  2.304561  2.333248  2.285436  2.328467  46000000     Monday
#
#   Status
# 0    red
# 1  green
# 2    red
# 3  green
# 4    red

# %% [markdown]
# #### Chart Donat

# %%
import matplotlib.pyplot as plt

# Contoh: df sudah punya kolom Status
# (kalau belum, bisa pakai kode sebelumnya untuk menambahkannya)

# Hitung jumlah masing-masing status
status_counts = df['Status'].value_counts()

# Warna donat
colors = {
    'green': '#2ecc71',   # hijau
    'red': '#e74c3c',     # merah
    'neutral': '#95a5a6'  # abu-abu
}

# Buat donut chart
fig, ax = plt.subplots(figsize=(6, 6))
wedges, texts, autotexts = ax.pie(
    status_counts,
    labels=status_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=[colors[k] for k in status_counts.index],
    wedgeprops=dict(width=0.4)  # buat efek donut
)

# Tambahkan teks di tengah
ax.text(0, 0, 'Status\nCandlestick', ha='center', va='center', fontsize=12, weight='bold')

plt.title('Distribusi Candle: Green, Red, dan Neutral', fontsize=14)
plt.show()

# %%
status_counts
# Out:
# Status
# green    3890
# red      3861
# Name: count, dtype: int64

# %% [markdown]
# #### LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#labeling
df['label_Day']            = le.fit_transform(df['Day'])
df.head()
# Out:
#         Date     Close      High       Low      Open    Volume        Day  \
# 0 1995-01-03  2.302169  2.352372  2.299778  2.352372  39545600    Tuesday
# 1 1995-01-04  2.318903  2.323684  2.275872  2.304559  51611200  Wednesday
# 2 1995-01-05  2.280653  2.333246  2.271091  2.328465  39824000   Thursday
# 3 1995-01-06  2.318903  2.342809  2.285434  2.290216  46681600     Friday
# 4 1995-01-09  2.304561  2.333248  2.285436  2.328467  46000000     Monday
#
#   Status  label_Day
# 0    red          3
# 1  green          4
# 2    red          2
# 3  green          0
# 4    red          1

# %% [markdown]
# #### Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib

# Contoh: buat dan fit scaler
scaler = MinMaxScaler()
cols = [
    'label_Day',
    'Close', 
    'High', 
    'Low',
    'Open',
    'Volume', 
]

# Dictionary untuk menyimpan hasil transformasi
scaled_data = {}

# Loop untuk setiap kolom
for col in cols:
    scaler = MinMaxScaler()
    df[[col]] = scaler.fit_transform(df[[col]])  # scaling per kolom
    joblib.dump(scaler, os.path.join(root_folder, f'scaler_{col}.pkl'))
    scaled_data[col] = scaler
    print(f"✅ Scaler for '{col}' saved as scaler_{col}.pkl")

print("\nAll individual scalers saved successfully!")
# Out:
# ✅ Scaler for 'label_Day' saved as scaler_label_Day.pkl
# ✅ Scaler for 'Close' saved as scaler_Close.pkl
# ✅ Scaler for 'High' saved as scaler_High.pkl
# ✅ Scaler for 'Low' saved as scaler_Low.pkl
# ✅ Scaler for 'Open' saved as scaler_Open.pkl
# ✅ Scaler for 'Volume' saved as scaler_Volume.pkl
#
# All individual scalers saved successfully!

# %%
df.head()
# Out:
#         Date     Close      High       Low      Open    Volume        Day  \
# 0 1995-01-03  0.000085  0.000147  0.000136  0.000191  0.055458    Tuesday
# 1 1995-01-04  0.000117  0.000095  0.000090  0.000104  0.076122  Wednesday
# 2 1995-01-05  0.000045  0.000113  0.000081  0.000147  0.055935   Thursday
# 3 1995-01-06  0.000117  0.000130  0.000108  0.000078  0.067679     Friday
# 4 1995-01-09  0.000090  0.000113  0.000108  0.000147  0.066512     Monday
#
#   Status  label_Day
# 0    red       0.75
# 1  green       1.00
# 2    red       0.50
# 3  green       0.00
# 4    red       0.25

# %% [markdown]
# #### Mapping label

# %%
import json
mapping_dicts = {}

cols = [
    'Day',
]

for col in cols:
    label_col = f"label_{col}"
    mapping_dicts[col] = dict(zip(df[col], df[label_col]))


with open(root_folder + 'label_mappings.json', 'w') as f:
    json.dump(mapping_dicts, f, indent=2)

rows = []
for col, mapping in mapping_dicts.items():
    for k, v in mapping.items():
        rows.append({'feature': col, 'original_value': k, 'label_value': v})

mapping_table = pd.DataFrame(rows)
print(mapping_table)
# Out:
#   feature original_value  label_value
# 0     Day        Tuesday         0.75
# 1     Day      Wednesday         1.00
# 2     Day       Thursday         0.50
# 3     Day         Friday         0.00
# 4     Day         Monday         0.25

# %% [markdown]
# #### Select Kolom To Trian

# %%
col_target = 'Status'
cols = [
    'Date',
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    'Volume',
    col_target
]
df = df[cols].copy()
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 1995-01-03       0.75  0.000085  0.000147  0.000136  0.000191  0.055458
# 1 1995-01-04       1.00  0.000117  0.000095  0.000090  0.000104  0.076122
# 2 1995-01-05       0.50  0.000045  0.000113  0.000081  0.000147  0.055935
# 3 1995-01-06       0.00  0.000117  0.000130  0.000108  0.000078  0.067679
# 4 1995-01-09       0.25  0.000090  0.000113  0.000108  0.000147  0.066512
#
#   Status
# 0    red
# 1  green
# 2    red
# 3  green
# 4    red

# %% [markdown]
# #### Tentukan target -> one-hot encoding

# %%
y_counts = df[col_target].value_counts(normalize=True)
labels = list(y_counts.index)

df_y_encoded = pd.get_dummies(df[col_target], prefix='y')

# Pastikan semua nama kolom lowercase dan spasi → underscore
df_y_encoded.columns = (
    df_y_encoded.columns.str.lower()
                        .str.replace(' ', '_')
)

# Gabungkan ke DataFrame utama
df = pd.concat([df.drop(col_target, axis=1), df_y_encoded.astype(int)], axis=1)
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 1995-01-03       0.75  0.000085  0.000147  0.000136  0.000191  0.055458
# 1 1995-01-04       1.00  0.000117  0.000095  0.000090  0.000104  0.076122
# 2 1995-01-05       0.50  0.000045  0.000113  0.000081  0.000147  0.055935
# 3 1995-01-06       0.00  0.000117  0.000130  0.000108  0.000078  0.067679
# 4 1995-01-09       0.25  0.000090  0.000113  0.000108  0.000147  0.066512
#
#    y_green  y_red
# 0        0      1
# 1        1      0
# 2        0      1
# 3        1      0
# 4        0      1

# %% [markdown]
# # Data Load To Train

# %% [markdown]
# #### select Future to traian

# %%
feature_cols = [
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    'Volume',
]
target_cols = [col for col in df.columns if col.startswith('y_')]

# %% [markdown]
# #### Split data

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

tgl_pembatas = '2020-01-01'
X_train = df[df['Date'] <= tgl_pembatas]
X_test  = df[df['Date'] > tgl_pembatas]
print(f'Train : f{X_train.shape}')
print(f'Test  : f{X_test.shape}')
# Out:
# Train : f(6294, 9)
# Test  : f(1457, 9)

# %% [markdown]
# #### DataLoader

# %%
from data_set import MultiLabelTimeSeriesDataset
seq_length = 20
slide      = 1
# Buat dataset dengan class kamu
train_dataset = MultiLabelTimeSeriesDataset(X_train,seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)
test_dataset  = MultiLabelTimeSeriesDataset(X_test, seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)

# Buat DataLoader
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Cek contoh batch
for X, y in train_loader:
    print("X shape:", X.shape)
    print("y shape:", y.shape)
    print(X[:3])  # contoh fitur
    print(y[:3])  # contoh label
    break
# Out:
# X shape: torch.Size([32, 20, 6])
# y shape: torch.Size([32, 2])
# tensor([[[0.7500, 0.0304, 0.0294, 0.0302, 0.0289, 0.1597],
#          [1.0000, 0.0303, 0.0295, 0.0306, 0.0295, 0.1318],
#          [0.5000, 0.0306, 0.0296, 0.0307, 0.0295, 0.1373],
#          [0.0000, 0.0306, 0.0297, 0.0307, 0.0298, 0.2656],
#          [0.2500, 0.0313, 0.0303, 0.0313, 0.0301, 0.1666],
#          [0.7500, 0.0309, 0.0301, 0.0311, 0.0301, 0.0982],
#          [1.0000, 0.0310, 0.0301, 0.0311, 0.0300, 0.0885],
#          [0.5000, 0.0308, 0.0298, 0.0310, 0.0298, 0.0961],
#          [0.0000, 0.0306, 0.0297, 0.0308, 0.0297, 0.1347],
#          [0.2500, 0.0303, 0.0294, 0.0299, 0.0294, 0.1460],
#          [0.7500, 0.0301, 0.0293, 0.0302, 0.0291, 0.1084],
#          [1.0000, 0.0303, 0.0293, 0.0302, 0.0292, 0.0906],
#          [0.0000, 0.0302, 0.0294, 0.0304, 0.0291, 0.0295],
#          [0.2500, 0.0305, 0.0296, 0.0305, 0.0292, 0.1026],
#          [0.7500, 0.0305, 0.0296, 0.0306, 0.0294, 0.1178],
#          [1.0000, 0.0311, 0.0300, 0.0308, 0.0296, 0.1588],
#          [0.5000, 0.0309, 0.0301, 0.0309, 0.0300, 0.1523],
#          [0.0000, 0.0311, 0.0302, 0.0312, 0.0299, 0.1187],
#          [0.2500, 0.0312, 0.0302, 0.0311, 0.0298, 0.0824],
#          [0.7500, 0.0308, 0.0301, 0.0310, 0.0300, 0.1790]],
#
#         [[0.5000, 0.0264, 0.0262, 0.0266, 0.0259, 0.0515],
#          [0.0000, 0.0262, 0.0258, 0.0264, 0.0255, 0.0578],
#          [0.2500, 0.0261, 0.0254, 0.0260, 0.0253, 0.0700],
#          [0.7500, 0.0255, 0.0252, 0.0254, 0.0252, 0.0874],
#          [0.5000, 0.0266, 0.0257, 0.0257, 0.0249, 0.1025],
#          [0.0000, 0.0267, 0.0257, 0.0264, 0.0256, 0.0829],
#          [0.2500, 0.0272, 0.0265, 0.0269, 0.0259, 0.0896],
#          [0.7500, 0.0278, 0.0269, 0.0274, 0.0264, 0.1256],
#          [1.0000, 0.0269, 0.0267, 0.0271, 0.0266, 0.0983],
#          [0.5000, 0.0278, 0.0269, 0.0273, 0.0263, 0.0936],
#          [0.0000, 0.0279, 0.0271, 0.0276, 0.0265, 0.1037],
#          [0.2500, 0.0282, 0.0273, 0.0281, 0.0273, 0.0919],
#          [0.7500, 0.0285, 0.0275, 0.0283, 0.0272, 0.0806],
#          [1.0000, 0.0281, 0.0276, 0.0283, 0.0275, 0.0898],
#          [0.5000, 0.0276, 0.0273, 0.0277, 0.0271, 0.1271],
#          [0.0000, 0.0253, 0.0253, 0.0255, 0.0253, 0.2547],
#          [0.7500, 0.0253, 0.0248, 0.0255, 0.0247, 0.1353],
#          [1.0000, 0.0251, 0.0249, 0.0252, 0.0245, 0.1366],
#          [0.5000, 0.0258, 0.0250, 0.0256, 0.0247, 0.1100],
#          [0.0000, 0.0244, 0.0247, 0.0245, 0.0248, 0.1642]],
#
#         [[0.2500, 0.0023, 0.0024, 0.0023, 0.0024, 0.1615],
#          [0.7500, 0.0022, 0.0022, 0.0021, 0.0022, 0.2723],
#          [1.0000, 0.0022, 0.0023, 0.0022, 0.0022, 0.2100],
#          [0.5000, 0.0023, 0.0022, 0.0021, 0.0020, 0.1822],
#          [0.0000, 0.0025, 0.0024, 0.0024, 0.0023, 0.1208],
#          [0.2500, 0.0025, 0.0025, 0.0024, 0.0025, 0.0978],
#          [0.7500, 0.0025, 0.0025, 0.0025, 0.0025, 0.0629],
#          [1.0000, 0.0027, 0.0027, 0.0027, 0.0027, 0.2350],
#          [0.5000, 0.0025, 0.0026, 0.0026, 0.0027, 0.1108],
#          [0.0000, 0.0027, 0.0026, 0.0025, 0.0025, 0.1542],
#          [0.2500, 0.0029, 0.0028, 0.0027, 0.0026, 0.1399],
#          [0.7500, 0.0028, 0.0028, 0.0028, 0.0028, 0.0961],
#          [1.0000, 0.0029, 0.0027, 0.0028, 0.0027, 0.0530],
#          [0.5000, 0.0029, 0.0029, 0.0029, 0.0028, 0.1154],
#          [0.0000, 0.0027, 0.0028, 0.0028, 0.0028, 0.1205],
#          [0.2500, 0.0025, 0.0027, 0.0026, 0.0027, 0.1770],
#          [0.7500, 0.0029, 0.0028, 0.0026, 0.0025, 0.1493],
#          [1.0000, 0.0028, 0.0028, 0.0028, 0.0029, 0.1782],
#          [0.5000, 0.0027, 0.0027, 0.0027, 0.0027, 0.1509],
#          [0.0000, 0.0025, 0.0026, 0.0026, 0.0026, 0.1136]]])
# tensor([[0., 1.],
#         [0., 1.],
#         [0., 1.]])

# %% [markdown]
# # Config

# %%
from jcopdl.callback import Callback, set_config
config = set_config({
    "labels"         : labels,
    "threshold"      : 0.5,
    "input_size"     : len(test_dataset[0][0][0]),
    "hidden_size"    : 32,
    "num_layers"     : 1,
    "num_classes"    : len(labels),
    "dropout"        : 0.1,
    "bidirectional"  : True,
    "early_stop_patience" : 30,
    "col_target"     : col_target,
    "feature_cols"   : feature_cols
})
config
# Out:
# Config(bidirectional=True, col_target=Status, dropout=0.1, early_stop_patience=30, feature_cols=['label_Day', 'Close', 'High', 'Low', 'Open', 'Volume'], hidden_size=32, input_size=6, labels=['green', 'red'], num_classes=2, num_layers=1, threshold=0.5)

# %% [markdown]
# # MCOC

# %% [markdown]
# #### Model - Criterion - Optimizer - Callback

# %%
from class_lib import GRU_MultiLabelClassifier
from torch import optim, nn
from jcopdl.callback import Callback
import torch.optim as optim

#Model input_size, hidden_size, num_layers, num_classes, dropout=0.2, bidirectional=False
model = GRU_MultiLabelClassifier(
    input_size=config.input_size, 
    hidden_size=config.hidden_size, 
    num_layers=config.num_layers, 
    num_classes=config.num_classes, 
    dropout=config.dropout, 
    bidirectional=config.bidirectional
).to(device)

#Criterion
criterion =nn.BCELoss()

# --- Pilihan Optimizer ---
# AdamW
optimizer_adamw = optim.AdamW(model.parameters(), lr=0.001)
# Adam
optimizer_adam = optim.Adam(model.parameters(), lr=0.001)
# SGD (Stochastic Gradient Descent)
optimizer_sgd = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# RMSprop
optimizer_rmsprop = optim.RMSprop(model.parameters(), lr=0.001, momentum=0.9)
# Adagrad
optimizer_adagrad = optim.Adagrad(model.parameters(), lr=0.01)
# Adadelta
optimizer_adadelta = optim.Adadelta(model.parameters(), lr=0.1)
# ASGD (Averaged SGD)
optimizer_asgd = optim.ASGD(model.parameters(), lr=0.01)

# --- Contoh cara memilih salah satu ---
optim = optimizer_sgd  # misalnya kita pakai RAdam

#Callback
callback = Callback(model, config, outdir=root_folder,early_stop_patience=config.early_stop_patience)

# %% [markdown]
# # Training

# %%
from train_and_evaluate import train_and_evaluate_multi_label

train_and_evaluate_multi_label(
    model=model,
    train_dataset=train_dataset,
    test_dataset=test_dataset,
    train_loader=train_loader,
    test_loader=test_loader,
    criterion=criterion,
    optim=optim,
    config=config,
    device=device,
    labels=labels,          
    callback=callback
)
# Out:
# ─────────────────────────────────────────────────── 🚀 EPOCH 1 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 435.63it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1005.70it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6937 │ 0.6943 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5067 │ 0.5160 │ │ green │  0.4976  │
# │ Subset Accuracy  │ 0.3857 │ 0.2484 │ │  red  │  0.4704  │
# │ Micro F1         │ 0.4344 │ 0.5680 │ └───────┴──────────┘
# │ Macro F1         │ 0.3064 │ 0.5552 │
# │ Overall Accuracy │ 0.4933 │ 0.4840 │
# └──────────────────┴────────┴────────┘
# Epoch     1
# Train_cost  = 0.6937 | Test_cost  = 0.6943 | Train_score = 0.4933 | Test_score = 0.4840 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 2 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 448.33it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1004.51it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6935 │ 0.6948 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5096 │ 0.5261 │ │ green │  0.4774  │
# │ Subset Accuracy  │ 0.3119 │ 0.3716 │ │  red  │  0.4704  │
# │ Micro F1         │ 0.3918 │ 0.5203 │ └───────┴──────────┘
# │ Macro F1         │ 0.3038 │ 0.4616 │
# │ Overall Accuracy │ 0.4904 │ 0.4739 │
# └──────────────────┴────────┴────────┘
# Epoch     2
# Train_cost  = 0.6935 | Test_cost  = 0.6948 | Train_score = 0.4904 | Test_score = 0.4739 |
# ==> EarlyStop patience =  1 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 3 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 451.60it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 970.59it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6933 │ 0.6953 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5064 │ 0.5303 │ │ green │  0.4704  │
# │ Subset Accuracy  │ 0.2091 │ 0.4662 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.3204 │ 0.4716 │ └───────┴──────────┘
# │ Macro F1         │ 0.3118 │ 0.3270 │
# │ Overall Accuracy │ 0.4936 │ 0.4697 │
# └──────────────────┴────────┴────────┘
# Epoch     3
# Train_cost  = 0.6933 | Test_cost  = 0.6953 | Train_score = 0.4936 | Test_score = 0.4697 |
# ==> EarlyStop patience =  2 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 4 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 391.74it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 959.42it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6933 │ 0.6955 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5028 │ 0.5313 │ │ green │  0.4683  │
# │ Subset Accuracy  │ 0.2198 │ 0.4676 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.3718 │ 0.4692 │ └───────┴──────────┘
# │ Macro F1         │ 0.3602 │ 0.3206 │
# │ Overall Accuracy │ 0.4972 │ 0.4687 │
# └──────────────────┴────────┴────────┘
# Epoch     4
# Train_cost  = 0.6933 | Test_cost  = 0.6955 | Train_score = 0.4972 | Test_score = 0.4687 |
# ==> EarlyStop patience =  3 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 5 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 444.42it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1022.82it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6957 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5002 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.2016 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4021 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3833 │ 0.3193 │
# │ Overall Accuracy │ 0.4998 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch     5
# Train_cost  = 0.6932 | Test_cost  = 0.6957 | Train_score = 0.4998 | Test_score = 0.4690 |
# ==> EarlyStop patience =  4 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 6 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 433.26it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 958.57it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6958 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4974 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.2734 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4096 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3457 │ 0.3193 │
# │ Overall Accuracy │ 0.5026 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch     6
# Train_cost  = 0.6932 | Test_cost  = 0.6958 | Train_score = 0.5026 | Test_score = 0.4690 |
# ==> EarlyStop patience =  5 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 7 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 425.03it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1001.34it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6960 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4943 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.4079 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4535 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3138 │ 0.3193 │
# │ Overall Accuracy │ 0.5057 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch     7
# Train_cost  = 0.6931 | Test_cost  = 0.6960 | Train_score = 0.5057 | Test_score = 0.4690 |
# ==> EarlyStop patience =  6 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 8 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 442.81it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1031.12it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6962 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4956 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.4739 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4889 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3282 │ 0.3193 │
# │ Overall Accuracy │ 0.5044 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch     8
# Train_cost  = 0.6932 | Test_cost  = 0.6962 | Train_score = 0.5044 | Test_score = 0.4690 |
# ==> EarlyStop patience =  7 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 9 ────────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 440.15it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1013.07it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6962 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4963 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.4316 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4666 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3195 │ 0.3193 │
# │ Overall Accuracy │ 0.5037 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch     9
# Train_cost  = 0.6932 | Test_cost  = 0.6962 | Train_score = 0.5037 | Test_score = 0.4690 |
# ==> EarlyStop patience =  8 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 10 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 439.23it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1066.87it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6961 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4948 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.4189 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4598 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3175 │ 0.3193 │
# │ Overall Accuracy │ 0.5052 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    10
# Train_cost  = 0.6932 | Test_cost  = 0.6961 | Train_score = 0.5052 | Test_score = 0.4690 |
# ==> EarlyStop patience =  9 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 11 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 450.73it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1053.90it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6958 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4939 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.4069 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4531 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3139 │ 0.3193 │
# │ Overall Accuracy │ 0.5061 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    11
# Train_cost  = 0.6932 | Test_cost  = 0.6958 | Train_score = 0.5061 | Test_score = 0.4690 |
# ==> EarlyStop patience = 10 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 12 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 453.33it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1047.32it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6957 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4937 │ 0.5313 │ │ green │  0.4683  │
# │ Subset Accuracy  │ 0.4045 │ 0.4676 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4517 │ 0.4692 │ └───────┴──────────┘
# │ Macro F1         │ 0.3132 │ 0.3206 │
# │ Overall Accuracy │ 0.5063 │ 0.4687 │
# └──────────────────┴────────┴────────┘
# Epoch    12
# Train_cost  = 0.6931 | Test_cost  = 0.6957 | Train_score = 0.5063 | Test_score = 0.4687 |
# ==> EarlyStop patience = 11 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 13 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 400.90it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1082.40it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6956 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4949 │ 0.5317 │ │ green │  0.4676  │
# │ Subset Accuracy  │ 0.4386 │ 0.4642 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4700 │ 0.4705 │ └───────┴──────────┘
# │ Macro F1         │ 0.3198 │ 0.3257 │
# │ Overall Accuracy │ 0.5051 │ 0.4683 │
# └──────────────────┴────────┴────────┘
# Epoch    13
# Train_cost  = 0.6932 | Test_cost  = 0.6956 | Train_score = 0.5051 | Test_score = 0.4683 |
# ==> EarlyStop patience = 12 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 14 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 455.68it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1022.12it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6955 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4939 │ 0.5282 │ │ green │  0.4746  │
# │ Subset Accuracy  │ 0.3522 │ 0.4509 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4226 │ 0.4826 │ └───────┴──────────┘
# │ Macro F1         │ 0.3081 │ 0.3606 │
# │ Overall Accuracy │ 0.5061 │ 0.4718 │
# └──────────────────┴────────┴────────┘
# Epoch    14
# Train_cost  = 0.6931 | Test_cost  = 0.6955 | Train_score = 0.5061 | Test_score = 0.4718 |
# ==> EarlyStop patience = 13 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 15 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 419.97it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1111.45it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6956 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4952 │ 0.5289 │ │ green │  0.4732  │
# │ Subset Accuracy  │ 0.4077 │ 0.4537 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4521 │ 0.4802 │ └───────┴──────────┘
# │ Macro F1         │ 0.3117 │ 0.3537 │
# │ Overall Accuracy │ 0.5048 │ 0.4711 │
# └──────────────────┴────────┴────────┘
# Epoch    15
# Train_cost  = 0.6931 | Test_cost  = 0.6956 | Train_score = 0.5048 | Test_score = 0.4711 |
# ==> EarlyStop patience = 14 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 16 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 427.85it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1042.93it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6956 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4942 │ 0.5306 │ │ green │  0.4697  │
# │ Subset Accuracy  │ 0.4310 │ 0.4565 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4660 │ 0.4761 │ └───────┴──────────┘
# │ Macro F1         │ 0.3181 │ 0.3430 │
# │ Overall Accuracy │ 0.5058 │ 0.4694 │
# └──────────────────┴────────┴────────┘
# Epoch    16
# Train_cost  = 0.6931 | Test_cost  = 0.6956 | Train_score = 0.5058 | Test_score = 0.4694 |
# ==> EarlyStop patience = 15 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 17 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 442.50it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1086.56it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6957 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4942 │ 0.5317 │ │ green │  0.4676  │
# │ Subset Accuracy  │ 0.4382 │ 0.4600 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4700 │ 0.4727 │ └───────┴──────────┘
# │ Macro F1         │ 0.3199 │ 0.3333 │
# │ Overall Accuracy │ 0.5058 │ 0.4683 │
# └──────────────────┴────────┴────────┘
# Epoch    17
# Train_cost  = 0.6931 | Test_cost  = 0.6957 | Train_score = 0.5058 | Test_score = 0.4683 |
# ==> EarlyStop patience = 16 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 18 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 438.89it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 929.24it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6956 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4935 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.4082 │ 0.4516 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4530 │ 0.4781 │ └───────┴──────────┘
# │ Macro F1         │ 0.3128 │ 0.3500 │
# │ Overall Accuracy │ 0.5065 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    18
# Train_cost  = 0.6931 | Test_cost  = 0.6956 | Train_score = 0.5065 | Test_score = 0.4690 |
# ==> EarlyStop patience = 17 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 19 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 411.70it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1044.14it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6955 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4947 │ 0.5278 │ │ green │  0.4753  │
# │ Subset Accuracy  │ 0.4335 │ 0.4342 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4671 │ 0.4915 │ └───────┴──────────┘
# │ Macro F1         │ 0.3185 │ 0.3869 │
# │ Overall Accuracy │ 0.5053 │ 0.4722 │
# └──────────────────┴────────┴────────┘
# Epoch    19
# Train_cost  = 0.6930 | Test_cost  = 0.6955 | Train_score = 0.5053 | Test_score = 0.4722 |
# ==> EarlyStop patience = 18 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 20 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 424.38it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1079.76it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6956 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4958 │ 0.5306 │ │ green │  0.4697  │
# │ Subset Accuracy  │ 0.4853 │ 0.4384 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4948 │ 0.4853 │ └───────┴──────────┘
# │ Macro F1         │ 0.3308 │ 0.3721 │
# │ Overall Accuracy │ 0.5042 │ 0.4694 │
# └──────────────────┴────────┴────────┘
# Epoch    20
# Train_cost  = 0.6931 | Test_cost  = 0.6956 | Train_score = 0.5042 | Test_score = 0.4694 |
# ==> EarlyStop patience = 19 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 21 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 448.65it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 863.51it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6955 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4943 │ 0.5268 │ │ green │  0.4774  │
# │ Subset Accuracy  │ 0.4238 │ 0.4280 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4617 │ 0.4960 │ └───────┴──────────┘
# │ Macro F1         │ 0.3161 │ 0.3988 │
# │ Overall Accuracy │ 0.5057 │ 0.4732 │
# └──────────────────┴────────┴────────┘
# Epoch    21
# Train_cost  = 0.6931 | Test_cost  = 0.6955 | Train_score = 0.5057 | Test_score = 0.4732 |
# ==> EarlyStop patience = 20 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 22 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 432.07it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1097.72it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6954 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4946 │ 0.5202 │ │ green │  0.4906  │
# │ Subset Accuracy  │ 0.4053 │ 0.4043 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4508 │ 0.5163 │ └───────┴──────────┘
# │ Macro F1         │ 0.3118 │ 0.4458 │
# │ Overall Accuracy │ 0.5054 │ 0.4798 │
# └──────────────────┴────────┴────────┘
# Epoch    22
# Train_cost  = 0.6931 | Test_cost  = 0.6954 | Train_score = 0.5054 | Test_score = 0.4798 |
# ==> EarlyStop patience = 21 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 23 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 474.98it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1192.69it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6953 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4947 │ 0.5247 │ │ green │  0.4816  │
# │ Subset Accuracy  │ 0.4584 │ 0.3598 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4811 │ 0.5296 │ └───────┴──────────┘
# │ Macro F1         │ 0.3249 │ 0.4791 │
# │ Overall Accuracy │ 0.5053 │ 0.4753 │
# └──────────────────┴────────┴────────┘
# Epoch    23
# Train_cost  = 0.6931 | Test_cost  = 0.6953 | Train_score = 0.5053 | Test_score = 0.4753 |
# ==> EarlyStop patience = 22 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 24 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 437.13it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1106.38it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6953 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4945 │ 0.5244 │ │ green │  0.4823  │
# │ Subset Accuracy  │ 0.4388 │ 0.3361 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4702 │ 0.5398 │ └───────┴──────────┘
# │ Macro F1         │ 0.3199 │ 0.4997 │
# │ Overall Accuracy │ 0.5055 │ 0.4756 │
# └──────────────────┴────────┴────────┘
# Epoch    24
# Train_cost  = 0.6931 | Test_cost  = 0.6953 | Train_score = 0.5055 | Test_score = 0.4756 |
# ==> EarlyStop patience = 23 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 25 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 442.80it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 810.46it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6952 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4930 │ 0.5219 │ │ green │  0.4871  │
# │ Subset Accuracy  │ 0.3492 │ 0.2895 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4194 │ 0.5609 │ └───────┴──────────┘
# │ Macro F1         │ 0.3192 │ 0.5369 │
# │ Overall Accuracy │ 0.5070 │ 0.4781 │
# └──────────────────┴────────┴────────┘
# Epoch    25
# Train_cost  = 0.6931 | Test_cost  = 0.6952 | Train_score = 0.5070 | Test_score = 0.4781 |
# ==> EarlyStop patience = 24 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 26 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 433.16it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1157.71it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6951 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4916 │ 0.5170 │ │ green │  0.4969  │
# │ Subset Accuracy  │ 0.3771 │ 0.2547 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4342 │ 0.5790 │ └───────┴──────────┘
# │ Macro F1         │ 0.3040 │ 0.5645 │
# │ Overall Accuracy │ 0.5084 │ 0.4830 │
# └──────────────────┴────────┴────────┘
# Epoch    26
# Train_cost  = 0.6931 | Test_cost  = 0.6951 | Train_score = 0.5084 | Test_score = 0.4830 |
# ==> EarlyStop patience = 25 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 27 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 483.57it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1159.89it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6949 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4934 │ 0.5167 │ │ green │  0.4976  │
# │ Subset Accuracy  │ 0.3589 │ 0.1510 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4221 │ 0.6122 │ └───────┴──────────┘
# │ Macro F1         │ 0.3045 │ 0.6092 │
# │ Overall Accuracy │ 0.5066 │ 0.4833 │
# └──────────────────┴────────┴────────┘
# Epoch    27
# Train_cost  = 0.6931 | Test_cost  = 0.6949 | Train_score = 0.5066 | Test_score = 0.4833 |
# ==> EarlyStop patience = 26 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 28 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 429.75it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1040.60it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6949 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4946 │ 0.5188 │ │ green │  0.4934  │
# │ Subset Accuracy  │ 0.3416 │ 0.1580 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4140 │ 0.6079 │ └───────┴──────────┘
# │ Macro F1         │ 0.3138 │ 0.6041 │
# │ Overall Accuracy │ 0.5054 │ 0.4812 │
# └──────────────────┴────────┴────────┘
# Epoch    28
# Train_cost  = 0.6930 | Test_cost  = 0.6949 | Train_score = 0.5054 | Test_score = 0.4812 |
# ==> EarlyStop patience = 27 | Best test_score: 0.4840
# ─────────────────────────────────────────────────── 🚀 EPOCH 29 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 477.19it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1113.17it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6951 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4923 │ 0.5157 │ │ green │  0.4997  │
# │ Subset Accuracy  │ 0.3948 │ 0.2443 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4452 │ 0.5842 │ └───────┴──────────┘
# │ Macro F1         │ 0.3091 │ 0.5719 │
# │ Overall Accuracy │ 0.5077 │ 0.4843 │
# └──────────────────┴────────┴────────┘
# Epoch    29
# Train_cost  = 0.6930 | Test_cost  = 0.6951 | Train_score = 0.5077 | Test_score = 0.4843 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 30 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 494.75it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1202.03it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6950 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4927 │ 0.5150 │ │ green │  0.5010  │
# │ Subset Accuracy  │ 0.3824 │ 0.1872 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4371 │ 0.6032 │ └───────┴──────────┘
# │ Macro F1         │ 0.3055 │ 0.5978 │
# │ Overall Accuracy │ 0.5073 │ 0.4850 │
# └──────────────────┴────────┴────────┘
# Epoch    30
# Train_cost  = 0.6930 | Test_cost  = 0.6950 | Train_score = 0.5073 | Test_score = 0.4850 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 31 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 436.60it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1023.66it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6950 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4925 │ 0.5164 │ │ green │  0.4983  │
# │ Subset Accuracy  │ 0.4155 │ 0.1816 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4577 │ 0.6034 │ └───────┴──────────┘
# │ Macro F1         │ 0.3146 │ 0.5982 │
# │ Overall Accuracy │ 0.5075 │ 0.4836 │
# └──────────────────┴────────┴────────┘
# Epoch    31
# Train_cost  = 0.6929 | Test_cost  = 0.6950 | Train_score = 0.5075 | Test_score = 0.4836 |
# ==> EarlyStop patience =  1 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 32 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 487.96it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1167.57it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6952 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4925 │ 0.5230 │ │ green │  0.4850  │
# │ Subset Accuracy  │ 0.4107 │ 0.3006 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4547 │ 0.5555 │ └───────┴──────────┘
# │ Macro F1         │ 0.3132 │ 0.5279 │
# │ Overall Accuracy │ 0.5075 │ 0.4770 │
# └──────────────────┴────────┴────────┘
# Epoch    32
# Train_cost  = 0.6930 | Test_cost  = 0.6952 | Train_score = 0.5075 | Test_score = 0.4770 |
# ==> EarlyStop patience =  2 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 33 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 493.99it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1191.09it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6951 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4928 │ 0.5177 │ │ green │  0.4955  │
# │ Subset Accuracy  │ 0.4115 │ 0.2422 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4553 │ 0.5825 │ └───────┴──────────┘
# │ Macro F1         │ 0.3137 │ 0.5698 │
# │ Overall Accuracy │ 0.5072 │ 0.4823 │
# └──────────────────┴────────┴────────┘
# Epoch    33
# Train_cost  = 0.6930 | Test_cost  = 0.6951 | Train_score = 0.5072 | Test_score = 0.4823 |
# ==> EarlyStop patience =  3 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 34 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 492.49it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1187.30it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6950 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4933 │ 0.5188 │ │ green │  0.4934  │
# │ Subset Accuracy  │ 0.4166 │ 0.2324 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4579 │ 0.5846 │ └───────┴──────────┘
# │ Macro F1         │ 0.3144 │ 0.5730 │
# │ Overall Accuracy │ 0.5067 │ 0.4812 │
# └──────────────────┴────────┴────────┘
# Epoch    34
# Train_cost  = 0.6930 | Test_cost  = 0.6950 | Train_score = 0.5067 | Test_score = 0.4812 |
# ==> EarlyStop patience =  4 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 35 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 490.58it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1155.43it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6951 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4934 │ 0.5195 │ │ green │  0.4920  │
# │ Subset Accuracy  │ 0.4087 │ 0.2429 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4531 │ 0.5803 │ └───────┴──────────┘
# │ Macro F1         │ 0.3125 │ 0.5669 │
# │ Overall Accuracy │ 0.5066 │ 0.4805 │
# └──────────────────┴────────┴────────┘
# Epoch    35
# Train_cost  = 0.6929 | Test_cost  = 0.6951 | Train_score = 0.5066 | Test_score = 0.4805 |
# ==> EarlyStop patience =  5 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 36 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 494.78it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1208.81it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6951 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4933 │ 0.5188 │ │ green │  0.4934  │
# │ Subset Accuracy  │ 0.4436 │ 0.2596 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4735 │ 0.5753 │ └───────┴──────────┘
# │ Macro F1         │ 0.3217 │ 0.5593 │
# │ Overall Accuracy │ 0.5067 │ 0.4812 │
# └──────────────────┴────────┴────────┘
# Epoch    36
# Train_cost  = 0.6930 | Test_cost  = 0.6951 | Train_score = 0.5067 | Test_score = 0.4812 |
# ==> EarlyStop patience =  6 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 37 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 497.76it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1152.61it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6949 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4918 │ 0.5150 │ │ green │  0.5010  │
# │ Subset Accuracy  │ 0.3771 │ 0.1788 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4400 │ 0.6058 │ └───────┴──────────┘
# │ Macro F1         │ 0.3177 │ 0.6011 │
# │ Overall Accuracy │ 0.5082 │ 0.4850 │
# └──────────────────┴────────┴────────┘
# Epoch    37
# Train_cost  = 0.6930 | Test_cost  = 0.6949 | Train_score = 0.5082 | Test_score = 0.4850 |
# ==> EarlyStop patience =  7 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 38 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 498.51it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1185.16it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6949 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4941 │ 0.5177 │ │ green │  0.4955  │
# │ Subset Accuracy  │ 0.4080 │ 0.2011 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4532 │ 0.5959 │ └───────┴──────────┘
# │ Macro F1         │ 0.3134 │ 0.5885 │
# │ Overall Accuracy │ 0.5059 │ 0.4823 │
# └──────────────────┴────────┴────────┘
# Epoch    38
# Train_cost  = 0.6930 | Test_cost  = 0.6949 | Train_score = 0.5059 | Test_score = 0.4823 |
# ==> EarlyStop patience =  8 | Best test_score: 0.4850
# ─────────────────────────────────────────────────── 🚀 EPOCH 39 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 498.06it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1229.99it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6947 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4953 │ 0.5125 │ │ green │  0.5059  │
# │ Subset Accuracy  │ 0.4058 │ 0.1482 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4520 │ 0.6173 │ └───────┴──────────┘
# │ Macro F1         │ 0.3135 │ 0.6150 │
# │ Overall Accuracy │ 0.5047 │ 0.4875 │
# └──────────────────┴────────┴────────┘
# Epoch    39
# Train_cost  = 0.6930 | Test_cost  = 0.6947 | Train_score = 0.5047 | Test_score = 0.4875 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 40 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 492.60it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1232.47it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6948 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4927 │ 0.5146 │ │ green │  0.5017  │
# │ Subset Accuracy  │ 0.4358 │ 0.1733 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4694 │ 0.6078 │ └───────┴──────────┘
# │ Macro F1         │ 0.3199 │ 0.6036 │
# │ Overall Accuracy │ 0.5073 │ 0.4854 │
# └──────────────────┴────────┴────────┘
# Epoch    40
# Train_cost  = 0.6930 | Test_cost  = 0.6948 | Train_score = 0.5073 | Test_score = 0.4854 |
# ==> EarlyStop patience =  1 | Best test_score: 0.4875
# ─────────────────────────────────────────────────── 🚀 EPOCH 41 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 500.97it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1061.70it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6948 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4931 │ 0.5143 │ │ green │  0.5024  │
# │ Subset Accuracy  │ 0.4173 │ 0.1531 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4584 │ 0.6141 │ └───────┴──────────┘
# │ Macro F1         │ 0.3150 │ 0.6113 │
# │ Overall Accuracy │ 0.5069 │ 0.4857 │
# └──────────────────┴────────┴────────┘
# Epoch    41
# Train_cost  = 0.6929 | Test_cost  = 0.6948 | Train_score = 0.5069 | Test_score = 0.4857 |
# ==> EarlyStop patience =  2 | Best test_score: 0.4875
# ─────────────────────────────────────────────────── 🚀 EPOCH 42 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 495.47it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1179.50it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6947 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4922 │ 0.5118 │ │ green │  0.5073  │
# │ Subset Accuracy  │ 0.4189 │ 0.1517 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4709 │ 0.6170 │ └───────┴──────────┘
# │ Macro F1         │ 0.4264 │ 0.6147 │
# │ Overall Accuracy │ 0.5078 │ 0.4882 │
# └──────────────────┴────────┴────────┘
# Epoch    42
# Train_cost  = 0.6929 | Test_cost  = 0.6947 | Train_score = 0.5078 | Test_score = 0.4882 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 43 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 492.62it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1147.50it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6947 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4922 │ 0.5136 │ │ green │  0.5038  │
# │ Subset Accuracy  │ 0.4216 │ 0.1545 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4620 │ 0.6144 │ └───────┴──────────┘
# │ Macro F1         │ 0.3179 │ 0.6117 │
# │ Overall Accuracy │ 0.5078 │ 0.4864 │
# └──────────────────┴────────┴────────┘
# Epoch    43
# Train_cost  = 0.6929 | Test_cost  = 0.6947 | Train_score = 0.5078 | Test_score = 0.4864 |
# ==> EarlyStop patience =  1 | Best test_score: 0.4882
# ─────────────────────────────────────────────────── 🚀 EPOCH 44 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 483.33it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1208.61it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6948 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4924 │ 0.5153 │ │ green │  0.5003  │
# │ Subset Accuracy  │ 0.4168 │ 0.1691 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4598 │ 0.6083 │ └───────┴──────────┘
# │ Macro F1         │ 0.3181 │ 0.6043 │
# │ Overall Accuracy │ 0.5076 │ 0.4847 │
# └──────────────────┴────────┴────────┘
# Epoch    44
# Train_cost  = 0.6930 | Test_cost  = 0.6948 | Train_score = 0.5076 | Test_score = 0.4847 |
# ==> EarlyStop patience =  2 | Best test_score: 0.4882
# ─────────────────────────────────────────────────── 🚀 EPOCH 45 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 421.39it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1145.80it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6946 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4935 │ 0.5139 │ │ green │  0.5031  │
# │ Subset Accuracy  │ 0.4254 │ 0.1308 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4633 │ 0.6208 │ └───────┴──────────┘
# │ Macro F1         │ 0.3177 │ 0.6192 │
# │ Overall Accuracy │ 0.5065 │ 0.4861 │
# └──────────────────┴────────┴────────┘
# Epoch    45
# Train_cost  = 0.6929 | Test_cost  = 0.6946 | Train_score = 0.5065 | Test_score = 0.4861 |
# ==> EarlyStop patience =  3 | Best test_score: 0.4882
# ─────────────────────────────────────────────────── 🚀 EPOCH 46 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 483.80it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 871.98it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6930 │ 0.6946 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4923 │ 0.5125 │ │ green │  0.5059  │
# │ Subset Accuracy  │ 0.4160 │ 0.1280 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4591 │ 0.6230 │ └───────┴──────────┘
# │ Macro F1         │ 0.3173 │ 0.6216 │
# │ Overall Accuracy │ 0.5077 │ 0.4875 │
# └──────────────────┴────────┴────────┘
# Epoch    46
# Train_cost  = 0.6930 | Test_cost  = 0.6946 | Train_score = 0.5077 | Test_score = 0.4875 |
# ==> EarlyStop patience =  4 | Best test_score: 0.4882
# ─────────────────────────────────────────────────── 🚀 EPOCH 47 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 424.39it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1175.37it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6929 │ 0.6945 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4934 │ 0.5122 │ │ green │  0.5066  │
# │ Subset Accuracy  │ 0.3827 │ 0.1197 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.4489 │ 0.6256 │ └───────┴──────────┘
# │ Macro F1         │ 0.3361 │ 0.6246 │
# │ Overall Accuracy │ 0.5066 │ 0.4878 │
# └──────────────────┴────────┴────────┘
# Epoch    47
# Train_cost  = 0.6929 | Test_cost  = 0.6945 | Train_score = 0.5066 | Test_score = 0.4878 |
# ==> EarlyStop patience =  5 | Best test_score: 0.4882
# ─────────────────────────────────────────────────── 🚀 EPOCH 48 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 474.91it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1192.17it/s]
# ...
# │ Subset Accuracy  │ 0.5043 │ 0.5261 │ │  red  │  0.5338  │
# │ Micro F1         │ 0.5153 │ 0.5358 │ └───────┴──────────┘
# │ Macro F1         │ 0.5135 │ 0.3655 │
# │ Overall Accuracy │ 0.5141 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch   222
# Train_cost  = 0.6924 | Test_cost  = 0.6924 | Train_score = 0.5141 | Test_score = 0.5327 |
# ==> EarlyStop patience = 15 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 223 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 495.56it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1074.50it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6922 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4872 │ 0.4673 │ │ green │  0.5310  │
# │ Subset Accuracy  │ 0.5032 │ 0.5261 │ │  red  │  0.5344  │
# │ Micro F1         │ 0.5126 │ 0.5358 │ └───────┴──────────┘
# │ Macro F1         │ 0.4971 │ 0.3666 │
# │ Overall Accuracy │ 0.5128 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch   223
# Train_cost  = 0.6922 | Test_cost  = 0.6924 | Train_score = 0.5128 | Test_score = 0.5327 |
# ==> EarlyStop patience = 16 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 224 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 486.74it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1207.07it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6924 │ 0.6925 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4857 │ 0.4676 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5037 │ 0.5261 │ │  red  │  0.5331  │
# │ Micro F1         │ 0.5148 │ 0.5353 │ └───────┴──────────┘
# │ Macro F1         │ 0.5110 │ 0.3641 │
# │ Overall Accuracy │ 0.5143 │ 0.5324 │
# └──────────────────┴────────┴────────┘
# Epoch   224
# Train_cost  = 0.6924 | Test_cost  = 0.6925 | Train_score = 0.5143 | Test_score = 0.5324 |
# ==> EarlyStop patience = 17 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 225 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 489.85it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1175.64it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6924 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4879 │ 0.4669 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.4998 │ 0.5261 │ │  red  │  0.5344  │
# │ Micro F1         │ 0.5115 │ 0.5363 │ └───────┴──────────┘
# │ Macro F1         │ 0.5061 │ 0.3669 │
# │ Overall Accuracy │ 0.5121 │ 0.5331 │
# └──────────────────┴────────┴────────┘
# Epoch   225
# Train_cost  = 0.6924 | Test_cost  = 0.6924 | Train_score = 0.5121 | Test_score = 0.5331 |
# ==> EarlyStop patience = 18 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 226 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 462.12it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1143.63it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6923 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4869 │ 0.4669 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5011 │ 0.5268 │ │  red  │  0.5344  │
# │ Micro F1         │ 0.5124 │ 0.5360 │ └───────┴──────────┘
# │ Macro F1         │ 0.5029 │ 0.3668 │
# │ Overall Accuracy │ 0.5131 │ 0.5331 │
# └──────────────────┴────────┴────────┘
# Epoch   226
# Train_cost  = 0.6923 | Test_cost  = 0.6924 | Train_score = 0.5131 | Test_score = 0.5331 |
# ==> EarlyStop patience = 19 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 227 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 493.57it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1223.39it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6924 │ 0.6925 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4876 │ 0.4676 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5010 │ 0.5261 │ │  red  │  0.5331  │
# │ Micro F1         │ 0.5112 │ 0.5353 │ └───────┴──────────┘
# │ Macro F1         │ 0.4967 │ 0.3641 │
# │ Overall Accuracy │ 0.5124 │ 0.5324 │
# └──────────────────┴────────┴────────┘
# Epoch   227
# Train_cost  = 0.6924 | Test_cost  = 0.6925 | Train_score = 0.5124 | Test_score = 0.5324 |
# ==> EarlyStop patience = 20 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 228 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 494.95it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 914.04it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6924 │ 0.6925 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4876 │ 0.4673 │ │ green │  0.5310  │
# │ Subset Accuracy  │ 0.4998 │ 0.5261 │ │  red  │  0.5344  │
# │ Micro F1         │ 0.5116 │ 0.5358 │ └───────┴──────────┘
# │ Macro F1         │ 0.5026 │ 0.3666 │
# │ Overall Accuracy │ 0.5124 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch   228
# Train_cost  = 0.6924 | Test_cost  = 0.6925 | Train_score = 0.5124 | Test_score = 0.5327 |
# ==> EarlyStop patience = 21 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 229 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 404.62it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 997.42it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6924 │ 0.6925 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4872 │ 0.4676 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5011 │ 0.5261 │ │  red  │  0.5331  │
# │ Micro F1         │ 0.5128 │ 0.5353 │ └───────┴──────────┘
# │ Macro F1         │ 0.5066 │ 0.3641 │
# │ Overall Accuracy │ 0.5128 │ 0.5324 │
# └──────────────────┴────────┴────────┘
# Epoch   229
# Train_cost  = 0.6924 | Test_cost  = 0.6925 | Train_score = 0.5128 | Test_score = 0.5324 |
# ==> EarlyStop patience = 22 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 230 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 421.86it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 900.91it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6923 │ 0.6926 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4882 │ 0.4680 │ │ green │  0.5310  │
# │ Subset Accuracy  │ 0.5008 │ 0.5289 │ │  red  │  0.5331  │
# │ Micro F1         │ 0.5112 │ 0.5335 │ └───────┴──────────┘
# │ Macro F1         │ 0.5001 │ 0.3569 │
# │ Overall Accuracy │ 0.5118 │ 0.5320 │
# └──────────────────┴────────┴────────┘
# Epoch   230
# Train_cost  = 0.6923 | Test_cost  = 0.6926 | Train_score = 0.5118 | Test_score = 0.5320 |
# ==> EarlyStop patience = 23 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 231 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 410.95it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1010.59it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6922 │ 0.6926 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4876 │ 0.4683 │ │ green │  0.5310  │
# │ Subset Accuracy  │ 0.5011 │ 0.5275 │ │  red  │  0.5324  │
# │ Micro F1         │ 0.5126 │ 0.5336 │ └───────┴──────────┘
# │ Macro F1         │ 0.5080 │ 0.3583 │
# │ Overall Accuracy │ 0.5124 │ 0.5317 │
# └──────────────────┴────────┴────────┘
# Epoch   231
# Train_cost  = 0.6922 | Test_cost  = 0.6926 | Train_score = 0.5124 | Test_score = 0.5317 |
# ==> EarlyStop patience = 24 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 232 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 429.13it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1002.42it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6923 │ 0.6926 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4853 │ 0.4680 │ │ green │  0.5310  │
# │ Subset Accuracy  │ 0.5033 │ 0.5261 │ │  red  │  0.5331  │
# │ Micro F1         │ 0.5153 │ 0.5348 │ └───────┴──────────┘
# │ Macro F1         │ 0.5108 │ 0.3638 │
# │ Overall Accuracy │ 0.5147 │ 0.5320 │
# └──────────────────┴────────┴────────┘
# Epoch   232
# Train_cost  = 0.6923 | Test_cost  = 0.6926 | Train_score = 0.5147 | Test_score = 0.5320 |
# ==> EarlyStop patience = 25 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 233 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 405.22it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 909.77it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6924 │ 0.6926 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4876 │ 0.4673 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5014 │ 0.5268 │ │  red  │  0.5338  │
# │ Micro F1         │ 0.5121 │ 0.5355 │ └───────┴──────────┘
# │ Macro F1         │ 0.4971 │ 0.3641 │
# │ Overall Accuracy │ 0.5124 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch   233
# Train_cost  = 0.6924 | Test_cost  = 0.6926 | Train_score = 0.5124 | Test_score = 0.5327 |
# ==> EarlyStop patience = 26 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 234 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 409.86it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 991.35it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6923 │ 0.6927 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4871 │ 0.4676 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5021 │ 0.5282 │ │  red  │  0.5331  │
# │ Micro F1         │ 0.5124 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.5012 │ 0.3599 │
# │ Overall Accuracy │ 0.5129 │ 0.5324 │
# └──────────────────┴────────┴────────┘
# Epoch   234
# Train_cost  = 0.6923 | Test_cost  = 0.6927 | Train_score = 0.5129 | Test_score = 0.5324 |
# ==> EarlyStop patience = 27 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 235 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 403.38it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 945.71it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6923 │ 0.6927 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4881 │ 0.4676 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5011 │ 0.5282 │ │  red  │  0.5331  │
# │ Micro F1         │ 0.5128 │ 0.5343 │ └───────┴──────────┘
# │ Macro F1         │ 0.5102 │ 0.3599 │
# │ Overall Accuracy │ 0.5119 │ 0.5324 │
# └──────────────────┴────────┴────────┘
# Epoch   235
# Train_cost  = 0.6923 | Test_cost  = 0.6927 | Train_score = 0.5119 | Test_score = 0.5324 |
# ==> EarlyStop patience = 28 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 236 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 441.66it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1006.89it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6925 │ 0.6927 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4884 │ 0.4673 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5002 │ 0.5268 │ │  red  │  0.5338  │
# │ Micro F1         │ 0.5109 │ 0.5355 │ └───────┴──────────┘
# │ Macro F1         │ 0.4977 │ 0.3641 │
# │ Overall Accuracy │ 0.5116 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch   236
# Train_cost  = 0.6925 | Test_cost  = 0.6927 | Train_score = 0.5116 | Test_score = 0.5327 |
# ==> EarlyStop patience = 29 | Best test_score: 0.5344
# ────────────────────────────────────────────────── 🚀 EPOCH 237 ───────────────────────────────────────────────────
# train: 100%|██████████| 197/197 [00:00<00:00, 459.68it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 1077.23it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6923 │ 0.6928 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4866 │ 0.4673 │ │ green │  0.5317  │
# │ Subset Accuracy  │ 0.5010 │ 0.5296 │ │  red  │  0.5338  │
# │ Micro F1         │ 0.5125 │ 0.5342 │ └───────┴──────────┘
# │ Macro F1         │ 0.5012 │ 0.3572 │
# │ Overall Accuracy │ 0.5134 │ 0.5327 │
# └──────────────────┴────────┴────────┘
# Epoch   237
# Train_cost  = 0.6923 | Test_cost  = 0.6928 | Train_score = 0.5134 | Test_score = 0.5327 |
# ==> EarlyStop patience = 30 | Best test_score: 0.5344
# ==> Execute Early Stopping at epoch: 237 | Best test_score: 0.5344
# ==> Best model is saved at timeseris/multi-label-clasification/rnn/microsoft_stock_data/
# ⏹️ Training dihentikan oleh early stopping.

# %% [markdown]
# # Evaluate

# %%
from evaluate import evaluate_multi_label

hsl = evaluate_multi_label(model, test_loader, target_cols,criterion, device, config.threshold)
# Out:
#        📊 Evaluasi Model         🎯 Per-Label Accuracy
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━┳━━━━━━━━━┓
# ┃ Metrik              ┃  Nilai ┃ ┃  Label  ┃ Akurasi ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━╇━━━━━━━━━┩
# │ 🔹 Overall Accuracy │ 0.5344 │ │ y_green │ 0.5317  │
# │ ✅ Subset  Accuracy │ 0.5233 │ │  y_red  │ 0.5372  │
# │ 💥 Loss (avg)       │ 0.6922 │ └─────────┴─────────┘
# │ 📉 Hamming Loss     │ 0.4656 │
# │ ⚖️  Micro F1-score   │ 0.5396 │
# │ 📈 Macro F1-score   │ 0.3790 │
# └─────────────────────┴────────┘

# %%
hsl = hsl['df']
b = hsl[hsl['Benar (%)'] == 100]
b.head(300)
# Out:
#          Target    Prediksi  Benar (%)
# 2    [1.0, 0.0]  [1.0, 0.0]      100.0
# 3    [1.0, 0.0]  [1.0, 0.0]      100.0
# 5    [1.0, 0.0]  [1.0, 0.0]      100.0
# 7    [1.0, 0.0]  [1.0, 0.0]      100.0
# 10   [1.0, 0.0]  [1.0, 0.0]      100.0
# ..          ...         ...        ...
# 585  [1.0, 0.0]  [1.0, 0.0]      100.0
# 586  [1.0, 0.0]  [1.0, 0.0]      100.0
# 587  [1.0, 0.0]  [1.0, 0.0]      100.0
# 590  [1.0, 0.0]  [1.0, 0.0]      100.0
# 593  [1.0, 0.0]  [1.0, 0.0]      100.0
#
# [300 rows x 3 columns]

# %%
b.shape
# Out:
# (752, 3)

# %%
s = hsl[hsl['Benar (%)'] == 0]
s.head(300)
# Out:
#          Target    Prediksi  Benar (%)
# 0    [0.0, 1.0]  [1.0, 0.0]        0.0
# 4    [0.0, 1.0]  [1.0, 0.0]        0.0
# 8    [0.0, 1.0]  [1.0, 0.0]        0.0
# 9    [0.0, 1.0]  [1.0, 0.0]        0.0
# 13   [0.0, 1.0]  [1.0, 0.0]        0.0
# ..          ...         ...        ...
# 672  [0.0, 1.0]  [1.0, 0.0]        0.0
# 673  [0.0, 1.0]  [1.0, 0.0]        0.0
# 677  [0.0, 1.0]  [1.0, 0.0]        0.0
# 678  [0.0, 1.0]  [1.0, 0.0]        0.0
# 679  [0.0, 1.0]  [1.0, 0.0]        0.0
#
# [300 rows x 3 columns]

# %%
s.shape
# Out:
# (653, 3)
