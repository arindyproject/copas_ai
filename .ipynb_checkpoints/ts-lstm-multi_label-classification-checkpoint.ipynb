# %% [markdown]
# #                                  timeseris Multi Label Clasification - LSTM

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import os
import numpy as np

# %%
file_name = "microsoft_stock_data"
root_folder = f'timeseris/multi-label-clasification/lstm/{file_name}/' 
os.makedirs(root_folder, exist_ok=True)

df = pd.read_csv('sample_data/'+file_name+'.csv')

df.head()
# Out:
#         Date     Close      High       Low      Open    Volume
# 0  3/26/1986  0.057906  0.058437  0.055781  0.056312  22752000
# 1  3/27/1986  0.058969  0.058969  0.057906  0.057906  16848000
# 2  3/31/1986  0.058437  0.058969  0.057375  0.058969  12873600
# 3   4/1/1986  0.057906  0.058437  0.057906  0.058437  11088000
# 4   4/2/1986  0.058437  0.059500  0.057906  0.057906  27014400

# %% [markdown]
# #### Pilih tahun mulai data

# %%
# Pastikan kolom Date dalam format datetime
df['Date'] = pd.to_datetime(df['Date'])

# Filter data mulai dari tahun 2000
df = df[df['Date'] >= '1998-01-01']

# (Opsional) urutkan berdasarkan tanggal
df = df.sort_values('Date').reset_index(drop=True)
df.head()
# Out:
#         Date      Close       High       Low       Open    Volume
# 0 1998-01-02  10.031051  10.059738  9.906738   9.916301  39748000
# 1 1998-01-05   9.973679  10.222303  9.782429  10.040616  80377600
# 2 1998-01-06  10.031051  10.174488  9.887613   9.925863  67834400
# 3 1998-01-07   9.911519  10.035831  9.753738   9.935425  61492800
# 4 1998-01-08   9.983242  10.107554  9.753742   9.839805  77619200

# %% [markdown]
# #### tambahkan status green, red, dan netral || DayName

# %%
# === Tambahkan kolom nama hari ===
df['Day'] =  df['Date'].dt.day_name()  # bahasa Inggris

# Buat kondisi
conditions = [
    df['Close'] > df['Open'],
    df['Close'] < df['Open'],
    df['Close'] == df['Open']
]
choices = ['green', 'red', 'red']

df['Status'] = np.select(conditions, choices)
df.head()
# Out:
#         Date      Close       High       Low       Open    Volume        Day  \
# 0 1998-01-02  10.031051  10.059738  9.906738   9.916301  39748000     Friday
# 1 1998-01-05   9.973679  10.222303  9.782429  10.040616  80377600     Monday
# 2 1998-01-06  10.031051  10.174488  9.887613   9.925863  67834400    Tuesday
# 3 1998-01-07   9.911519  10.035831  9.753738   9.935425  61492800  Wednesday
# 4 1998-01-08   9.983242  10.107554  9.753742   9.839805  77619200   Thursday
#
#   Status
# 0  green
# 1    red
# 2  green
# 3    red
# 4  green

# %% [markdown]
# #### Chart Donat

# %%
import matplotlib.pyplot as plt

# Contoh: df sudah punya kolom Status
# (kalau belum, bisa pakai kode sebelumnya untuk menambahkannya)

# Hitung jumlah masing-masing status
status_counts = df['Status'].value_counts()

# Warna donat
colors = {
    'green': '#2ecc71',   # hijau
    'red': '#e74c3c',     # merah
    'neutral': '#95a5a6'  # abu-abu
}

# Buat donut chart
fig, ax = plt.subplots(figsize=(6, 6))
wedges, texts, autotexts = ax.pie(
    status_counts,
    labels=status_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=[colors[k] for k in status_counts.index],
    wedgeprops=dict(width=0.4)  # buat efek donut
)

# Tambahkan teks di tengah
ax.text(0, 0, 'Status\nCandlestick', ha='center', va='center', fontsize=12, weight='bold')

plt.title('Distribusi Candle: Green, Red, dan Neutral', fontsize=14)
plt.show()

# %%
status_counts
# Out:
# Status
# green    3521
# red      3471
# Name: count, dtype: int64

# %% [markdown]
# #### LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#labeling
df['label_Day']            = le.fit_transform(df['Day'])
df.head()
# Out:
#         Date      Close       High       Low       Open    Volume        Day  \
# 0 1998-01-02  10.031051  10.059738  9.906738   9.916301  39748000     Friday
# 1 1998-01-05   9.973679  10.222303  9.782429  10.040616  80377600     Monday
# 2 1998-01-06  10.031051  10.174488  9.887613   9.925863  67834400    Tuesday
# 3 1998-01-07   9.911519  10.035831  9.753738   9.935425  61492800  Wednesday
# 4 1998-01-08   9.983242  10.107554  9.753742   9.839805  77619200   Thursday
#
#   Status  label_Day
# 0  green          0
# 1    red          1
# 2  green          3
# 3    red          4
# 4  green          2

# %% [markdown]
# #### Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib

# Contoh: buat dan fit scaler
scaler = MinMaxScaler()
cols = [
    'label_Day',
    'Close', 
    'High', 
    'Low',
    'Open',
    'Volume', 
]

# Dictionary untuk menyimpan hasil transformasi
scaled_data = {}

# Loop untuk setiap kolom
for col in cols:
    scaler = MinMaxScaler()
    df[[col]] = scaler.fit_transform(df[[col]])  # scaling per kolom
    joblib.dump(scaler, os.path.join(root_folder, f'scaler_{col}.pkl'))
    scaled_data[col] = scaler
    print(f"✅ Scaler for '{col}' saved as scaler_{col}.pkl")

print("\nAll individual scalers saved successfully!")
# Out:
# ✅ Scaler for 'label_Day' saved as scaler_label_Day.pkl
# ✅ Scaler for 'Close' saved as scaler_Close.pkl
# ✅ Scaler for 'High' saved as scaler_High.pkl
# ✅ Scaler for 'Low' saved as scaler_Low.pkl
# ✅ Scaler for 'Open' saved as scaler_Open.pkl
# ✅ Scaler for 'Volume' saved as scaler_Volume.pkl
#
# All individual scalers saved successfully!

# %%
df.head()
# Out:
#         Date     Close      High       Low      Open    Volume        Day  \
# 0 1998-01-02  0.000601  0.000211  0.000752  0.000702  0.055804     Friday
# 1 1998-01-05  0.000492  0.000509  0.000513  0.000930  0.125389     Monday
# 2 1998-01-06  0.000601  0.000421  0.000715  0.000720  0.103907    Tuesday
# 3 1998-01-07  0.000373  0.000167  0.000458  0.000737  0.093046  Wednesday
# 4 1998-01-08  0.000510  0.000299  0.000458  0.000562  0.120665   Thursday
#
#   Status  label_Day
# 0  green       0.00
# 1    red       0.25
# 2  green       0.75
# 3    red       1.00
# 4  green       0.50

# %% [markdown]
# #### Mapping label

# %%
import json
mapping_dicts = {}

cols = [
    'Day',
]

for col in cols:
    label_col = f"label_{col}"
    mapping_dicts[col] = dict(zip(df[col], df[label_col]))


with open(root_folder + 'label_mappings.json', 'w') as f:
    json.dump(mapping_dicts, f, indent=2)

rows = []
for col, mapping in mapping_dicts.items():
    for k, v in mapping.items():
        rows.append({'feature': col, 'original_value': k, 'label_value': v})

mapping_table = pd.DataFrame(rows)
print(mapping_table)
# Out:
#   feature original_value  label_value
# 0     Day         Friday         0.00
# 1     Day         Monday         0.25
# 2     Day        Tuesday         0.75
# 3     Day      Wednesday         1.00
# 4     Day       Thursday         0.50

# %% [markdown]
# #### Select Kolom To Trian

# %%
col_target = 'Status'
cols = [
    'Date',
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    'Volume',
    col_target
]
df = df[cols].copy()
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 1998-01-02       0.00  0.000601  0.000211  0.000752  0.000702  0.055804
# 1 1998-01-05       0.25  0.000492  0.000509  0.000513  0.000930  0.125389
# 2 1998-01-06       0.75  0.000601  0.000421  0.000715  0.000720  0.103907
# 3 1998-01-07       1.00  0.000373  0.000167  0.000458  0.000737  0.093046
# 4 1998-01-08       0.50  0.000510  0.000299  0.000458  0.000562  0.120665
#
#   Status
# 0  green
# 1    red
# 2  green
# 3    red
# 4  green

# %% [markdown]
# #### Tentukan target -> one-hot encoding

# %%
y_counts = df[col_target].value_counts(normalize=True)
labels = list(y_counts.index)

df_y_encoded = pd.get_dummies(df[col_target], prefix='y')

# Pastikan semua nama kolom lowercase dan spasi → underscore
df_y_encoded.columns = (
    df_y_encoded.columns.str.lower()
                        .str.replace(' ', '_')
)

# Gabungkan ke DataFrame utama
df = pd.concat([df.drop(col_target, axis=1), df_y_encoded.astype(int)], axis=1)
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 1998-01-02       0.00  0.000601  0.000211  0.000752  0.000702  0.055804
# 1 1998-01-05       0.25  0.000492  0.000509  0.000513  0.000930  0.125389
# 2 1998-01-06       0.75  0.000601  0.000421  0.000715  0.000720  0.103907
# 3 1998-01-07       1.00  0.000373  0.000167  0.000458  0.000737  0.093046
# 4 1998-01-08       0.50  0.000510  0.000299  0.000458  0.000562  0.120665
#
#    y_green  y_red
# 0        1      0
# 1        0      1
# 2        1      0
# 3        0      1
# 4        1      0

# %% [markdown]
# # Data Load To Train

# %% [markdown]
# #### select Future to traian

# %%
feature_cols = [
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    'Volume',
]
target_cols = [col for col in df.columns if col.startswith('y_')]

# %% [markdown]
# #### Split data

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

tgl_pembatas = '2021-01-01'
X_train = df[df['Date'] <= tgl_pembatas]
X_test  = df[df['Date'] > tgl_pembatas]
print(f'Train : f{X_train.shape}')
print(f'Test  : f{X_test.shape}')
# Out:
# Train : f(5788, 9)
# Test  : f(1204, 9)

# %% [markdown]
# #### DataLoader

# %%
from data_set import MultiLabelTimeSeriesDataset
seq_length = 20
slide      = 1
# Buat dataset dengan class kamu
train_dataset = MultiLabelTimeSeriesDataset(X_train,seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)
test_dataset  = MultiLabelTimeSeriesDataset(X_test, seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)

# Buat DataLoader
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Cek contoh batch
for X, y in train_loader:
    print("X shape:", X.shape)
    print("y shape:", y.shape)
    print(X[:3])  # contoh fitur
    print(y[:3])  # contoh label
    break
# Out:
# X shape: torch.Size([32, 20, 6])
# y shape: torch.Size([32, 2])
# tensor([[[0.0000e+00, 6.0102e-04, 2.1070e-04, 7.5178e-04, 7.0211e-04,
#           5.5804e-02],
#          [2.5000e-01, 4.9175e-04, 5.0921e-04, 5.1341e-04, 9.3030e-04,
#           1.2539e-01],
#          [7.5000e-01, 6.0102e-04, 4.2141e-04, 7.1510e-04, 7.1966e-04,
#           1.0391e-01],
#          [1.0000e+00, 3.7336e-04, 1.6681e-04, 4.5840e-04, 7.3721e-04,
#           9.3046e-02],
#          [5.0000e-01, 5.0996e-04, 2.9851e-04, 4.5841e-04, 5.6169e-04,
#           1.2066e-01],
#          [0.0000e+00, 0.0000e+00, 2.1070e-04, 2.2003e-04, 7.6354e-04,
#           1.3765e-01],
#          [2.5000e-01, 3.6426e-04, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           1.2199e-01],
#          [7.5000e-01, 7.4672e-04, 3.1606e-04, 5.5008e-04, 6.8456e-04,
#           1.0238e-01],
#          [1.0000e+00, 6.0102e-04, 3.5118e-04, 7.1510e-04, 1.0532e-03,
#           8.1539e-02],
#          [5.0000e-01, 7.7404e-04, 4.2141e-04, 8.0678e-04, 8.0743e-04,
#           7.4429e-02],
#          [0.0000e+00, 1.2020e-03, 7.5503e-04, 1.1643e-03, 1.0883e-03,
#           1.1266e-01],
#          [7.5000e-01, 1.5754e-03, 1.1238e-03, 1.4119e-03, 1.3340e-03,
#           9.8977e-02],
#          [1.0000e+00, 1.4570e-03, 1.1852e-03, 1.6503e-03, 1.7728e-03,
#           1.3428e-01],
#          [5.0000e-01, 1.6938e-03, 1.3872e-03, 1.6044e-03, 1.5359e-03,
#           2.6028e-01],
#          [0.0000e+00, 1.6391e-03, 1.3257e-03, 1.8084e-03, 1.9835e-03,
#           9.6161e-02],
#          [2.5000e-01, 2.1491e-03, 1.6681e-03, 2.0651e-03, 2.1414e-03,
#           1.1494e-01],
#          [7.5000e-01, 2.6500e-03, 2.2300e-03, 2.5212e-03, 2.4925e-03,
#           1.5478e-01],
#          [1.0000e+00, 3.2054e-03, 2.7392e-03, 3.0988e-03, 3.0366e-03,
#           1.2369e-01],
#          [5.0000e-01, 3.0962e-03, 2.8270e-03, 3.3922e-03, 3.4140e-03,
#           1.1373e-01],
#          [0.0000e+00, 3.2328e-03, 2.8094e-03, 3.4105e-03, 3.3701e-03,
#           7.3485e-02]],
#
#         [[2.5000e-01, 4.9175e-04, 5.0921e-04, 5.1341e-04, 9.3030e-04,
#           1.2539e-01],
#          [7.5000e-01, 6.0102e-04, 4.2141e-04, 7.1510e-04, 7.1966e-04,
#           1.0391e-01],
#          [1.0000e+00, 3.7336e-04, 1.6681e-04, 4.5840e-04, 7.3721e-04,
#           9.3046e-02],
#          [5.0000e-01, 5.0996e-04, 2.9851e-04, 4.5841e-04, 5.6169e-04,
#           1.2066e-01],
#          [0.0000e+00, 0.0000e+00, 2.1070e-04, 2.2003e-04, 7.6354e-04,
#           1.3765e-01],
#          [2.5000e-01, 3.6426e-04, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           1.2199e-01],
#          [7.5000e-01, 7.4672e-04, 3.1606e-04, 5.5008e-04, 6.8456e-04,
#           1.0238e-01],
#          [1.0000e+00, 6.0102e-04, 3.5118e-04, 7.1510e-04, 1.0532e-03,
#           8.1539e-02],
#          [5.0000e-01, 7.7404e-04, 4.2141e-04, 8.0678e-04, 8.0743e-04,
#           7.4429e-02],
#          [0.0000e+00, 1.2020e-03, 7.5503e-04, 1.1643e-03, 1.0883e-03,
#           1.1266e-01],
#          [7.5000e-01, 1.5754e-03, 1.1238e-03, 1.4119e-03, 1.3340e-03,
#           9.8977e-02],
#          [1.0000e+00, 1.4570e-03, 1.1852e-03, 1.6503e-03, 1.7728e-03,
#           1.3428e-01],
#          [5.0000e-01, 1.6938e-03, 1.3872e-03, 1.6044e-03, 1.5359e-03,
#           2.6028e-01],
#          [0.0000e+00, 1.6391e-03, 1.3257e-03, 1.8084e-03, 1.9835e-03,
#           9.6161e-02],
#          [2.5000e-01, 2.1491e-03, 1.6681e-03, 2.0651e-03, 2.1414e-03,
#           1.1494e-01],
#          [7.5000e-01, 2.6500e-03, 2.2300e-03, 2.5212e-03, 2.4925e-03,
#           1.5478e-01],
#          [1.0000e+00, 3.2054e-03, 2.7392e-03, 3.0988e-03, 3.0366e-03,
#           1.2369e-01],
#          [5.0000e-01, 3.0962e-03, 2.8270e-03, 3.3922e-03, 3.4140e-03,
#           1.1373e-01],
#          [0.0000e+00, 3.2328e-03, 2.8094e-03, 3.4105e-03, 3.3701e-03,
#           7.3485e-02],
#          [2.5000e-01, 4.0614e-03, 3.5293e-03, 3.8322e-03, 3.8089e-03,
#           1.5625e-01]],
#
#         [[7.5000e-01, 6.0102e-04, 4.2141e-04, 7.1510e-04, 7.1966e-04,
#           1.0391e-01],
#          [1.0000e+00, 3.7336e-04, 1.6681e-04, 4.5840e-04, 7.3721e-04,
#           9.3046e-02],
#          [5.0000e-01, 5.0996e-04, 2.9851e-04, 4.5841e-04, 5.6169e-04,
#           1.2066e-01],
#          [0.0000e+00, 0.0000e+00, 2.1070e-04, 2.2003e-04, 7.6354e-04,
#           1.3765e-01],
#          [2.5000e-01, 3.6426e-04, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           1.2199e-01],
#          [7.5000e-01, 7.4672e-04, 3.1606e-04, 5.5008e-04, 6.8456e-04,
#           1.0238e-01],
#          [1.0000e+00, 6.0102e-04, 3.5118e-04, 7.1510e-04, 1.0532e-03,
#           8.1539e-02],
#          [5.0000e-01, 7.7404e-04, 4.2141e-04, 8.0678e-04, 8.0743e-04,
#           7.4429e-02],
#          [0.0000e+00, 1.2020e-03, 7.5503e-04, 1.1643e-03, 1.0883e-03,
#           1.1266e-01],
#          [7.5000e-01, 1.5754e-03, 1.1238e-03, 1.4119e-03, 1.3340e-03,
#           9.8977e-02],
#          [1.0000e+00, 1.4570e-03, 1.1852e-03, 1.6503e-03, 1.7728e-03,
#           1.3428e-01],
#          [5.0000e-01, 1.6938e-03, 1.3872e-03, 1.6044e-03, 1.5359e-03,
#           2.6028e-01],
#          [0.0000e+00, 1.6391e-03, 1.3257e-03, 1.8084e-03, 1.9835e-03,
#           9.6161e-02],
#          [2.5000e-01, 2.1491e-03, 1.6681e-03, 2.0651e-03, 2.1414e-03,
#           1.1494e-01],
#          [7.5000e-01, 2.6500e-03, 2.2300e-03, 2.5212e-03, 2.4925e-03,
#           1.5478e-01],
#          [1.0000e+00, 3.2054e-03, 2.7392e-03, 3.0988e-03, 3.0366e-03,
#           1.2369e-01],
#          [5.0000e-01, 3.0962e-03, 2.8270e-03, 3.3922e-03, 3.4140e-03,
#           1.1373e-01],
#          [0.0000e+00, 3.2328e-03, 2.8094e-03, 3.4105e-03, 3.3701e-03,
#           7.3485e-02],
#          [2.5000e-01, 4.0614e-03, 3.5293e-03, 3.8322e-03, 3.8089e-03,
#           1.5625e-01],
#          [7.5000e-01, 4.2071e-03, 3.6698e-03, 4.3181e-03, 4.2829e-03,
#           9.2843e-02]]])
# tensor([[1., 0.],
#         [1., 0.],
#         [1., 0.]])

# %% [markdown]
# # Config

# %%
from jcopdl.callback import Callback, set_config
config = set_config({
    "labels"         : labels,
    "threshold"      : 0.5,
    "input_size"     : len(test_dataset[0][0][0]),
    "hidden_size"    : 8,
    "num_layers"     : 2,
    "num_classes"    : len(labels),
    "dropout"        : 0.0,
    "bidirectional"  : True,
    "early_stop_patience" : 30,
    "col_target"     : col_target,
    "feature_cols"   : feature_cols
})
config
# Out:
# Config(bidirectional=True, col_target=Status, dropout=0.0, early_stop_patience=30, feature_cols=['label_Day', 'Close', 'High', 'Low', 'Open', 'Volume'], hidden_size=8, input_size=6, labels=['green', 'red'], num_classes=2, num_layers=2, threshold=0.5)

# %% [markdown]
# # MCOC

# %% [markdown]
# #### Model - Criterion - Optimizer - Callback

# %%
from class_lib import LSTM_MultiLabelClassifier
from torch import optim, nn
from jcopdl.callback import Callback
import torch.optim as optim

#Model input_size, hidden_size, num_layers, num_classes, dropout=0.2, bidirectional=False
model = LSTM_MultiLabelClassifier(
    input_size=config.input_size, 
    hidden_size=config.hidden_size, 
    num_layers=config.num_layers, 
    num_classes=config.num_classes, 
    dropout=config.dropout, 
    bidirectional=config.bidirectional
).to(device)

#Criterion
criterion =nn.BCELoss()

# --- Pilihan Optimizer ---
# AdamW
optimizer_adamw = optim.AdamW(model.parameters(), lr=0.001)
# Adam
optimizer_adam = optim.Adam(model.parameters(), lr=0.001)
# SGD (Stochastic Gradient Descent)
optimizer_sgd = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# RMSprop
optimizer_rmsprop = optim.RMSprop(model.parameters(), lr=0.001, momentum=0.9)
# Adagrad
optimizer_adagrad = optim.Adagrad(model.parameters(), lr=0.01)
# Adadelta
optimizer_adadelta = optim.Adadelta(model.parameters(), lr=0.1)
# ASGD (Averaged SGD)
optimizer_asgd = optim.ASGD(model.parameters(), lr=0.01)

# --- Contoh cara memilih salah satu ---
optim = optimizer_sgd  # misalnya kita pakai RAdam

#Callback
callback = Callback(model, config, outdir=root_folder,early_stop_patience=config.early_stop_patience)

# %% [markdown]
# # Training

# %%
from train_and_evaluate import train_and_evaluate_multi_label

train_and_evaluate_multi_label(
    model=model,
    train_dataset=train_dataset,
    test_dataset=test_dataset,
    train_loader=train_loader,
    test_loader=test_loader,
    criterion=criterion,
    optim=optim,
    config=config,
    device=device,
    labels=labels,          
    callback=callback
)
# Out:
# ─────────────────────────────────────────────────── 🚀 EPOCH 1 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 259.07it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 679.58it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6956 │ 0.6914 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5028 │ 0.4696 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.4972 │ 0.5304 │ │  red  │  0.5304  │
# │ Micro F1         │ 0.4972 │ 0.5304 │ └───────┴──────────┘
# │ Macro F1         │ 0.3321 │ 0.3466 │
# │ Overall Accuracy │ 0.4972 │ 0.5304 │
# └──────────────────┴────────┴────────┘
# Epoch     1
# Train_cost  = 0.6956 | Test_cost  = 0.6914 | Train_score = 0.4972 | Test_score = 0.5304 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 2 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 283.20it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 719.42it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6946 │ 0.6917 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5028 │ 0.4696 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.4972 │ 0.5304 │ │  red  │  0.5304  │
# │ Micro F1         │ 0.4972 │ 0.5304 │ └───────┴──────────┘
# │ Macro F1         │ 0.3321 │ 0.3466 │
# │ Overall Accuracy │ 0.4972 │ 0.5304 │
# └──────────────────┴────────┴────────┘
# Epoch     2
# Train_cost  = 0.6946 | Test_cost  = 0.6917 | Train_score = 0.4972 | Test_score = 0.5304 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5304
# ─────────────────────────────────────────────────── 🚀 EPOCH 3 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 276.91it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 715.92it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6940 │ 0.6921 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5028 │ 0.4696 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.4972 │ 0.5304 │ │  red  │  0.5304  │
# │ Micro F1         │ 0.4972 │ 0.5304 │ └───────┴──────────┘
# │ Macro F1         │ 0.3321 │ 0.3466 │
# │ Overall Accuracy │ 0.4972 │ 0.5304 │
# └──────────────────┴────────┴────────┘
# Epoch     3
# Train_cost  = 0.6940 | Test_cost  = 0.6921 | Train_score = 0.4972 | Test_score = 0.5304 |
# ==> EarlyStop patience =  2 | Best test_score: 0.5304
# ─────────────────────────────────────────────────── 🚀 EPOCH 4 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 268.16it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 719.03it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6936 │ 0.6924 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5028 │ 0.4696 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.4972 │ 0.5304 │ │  red  │  0.5304  │
# │ Micro F1         │ 0.4972 │ 0.5304 │ └───────┴──────────┘
# │ Macro F1         │ 0.3321 │ 0.3466 │
# │ Overall Accuracy │ 0.4972 │ 0.5304 │
# └──────────────────┴────────┴────────┘
# Epoch     4
# Train_cost  = 0.6936 | Test_cost  = 0.6924 | Train_score = 0.4972 | Test_score = 0.5304 |
# ==> EarlyStop patience =  3 | Best test_score: 0.5304
# ─────────────────────────────────────────────────── 🚀 EPOCH 5 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 277.35it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 578.90it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6935 │ 0.6927 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5028 │ 0.4692 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.4972 │ 0.4932 │ │  red  │  0.5312  │
# │ Micro F1         │ 0.4972 │ 0.5478 │ └───────┴──────────┘
# │ Macro F1         │ 0.3321 │ 0.4163 │
# │ Overall Accuracy │ 0.4972 │ 0.5308 │
# └──────────────────┴────────┴────────┘
# Epoch     5
# Train_cost  = 0.6935 | Test_cost  = 0.6927 | Train_score = 0.4972 | Test_score = 0.5308 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 6 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 264.59it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 710.54it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6934 │ 0.6929 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5028 │ 0.4869 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.4972 │ 0.2872 │ │  red  │  0.4958  │
# │ Micro F1         │ 0.4972 │ 0.6028 │ └───────┴──────────┘
# │ Macro F1         │ 0.3321 │ 0.5730 │
# │ Overall Accuracy │ 0.4972 │ 0.5131 │
# └──────────────────┴────────┴────────┘
# Epoch     6
# Train_cost  = 0.6934 | Test_cost  = 0.6929 | Train_score = 0.4972 | Test_score = 0.5131 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 7 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 255.53it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 580.27it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6933 │ 0.6931 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5020 │ 0.4962 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.4121 │ 0.0752 │ │  red  │  0.4772  │
# │ Micro F1         │ 0.4526 │ 0.6527 │ └───────┴──────────┘
# │ Macro F1         │ 0.3139 │ 0.6496 │
# │ Overall Accuracy │ 0.4980 │ 0.5038 │
# └──────────────────┴────────┴────────┘
# Epoch     7
# Train_cost  = 0.6933 | Test_cost  = 0.6931 | Train_score = 0.4980 | Test_score = 0.5038 |
# ==> EarlyStop patience =  2 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 8 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 269.95it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 679.59it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6933 │ 0.6932 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5072 │ 0.5000 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.2346 │ 0.0000 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.3524 │ 0.6667 │ └───────┴──────────┘
# │ Macro F1         │ 0.3065 │ 0.6661 │
# │ Overall Accuracy │ 0.4928 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     8
# Train_cost  = 0.6933 | Test_cost  = 0.6932 | Train_score = 0.4928 | Test_score = 0.5000 |
# ==> EarlyStop patience =  3 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 9 ────────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 275.52it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 695.55it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6933 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5079 │ 0.5000 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.2613 │ 0.0000 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.3885 │ 0.6667 │ └───────┴──────────┘
# │ Macro F1         │ 0.3884 │ 0.6661 │
# │ Overall Accuracy │ 0.4921 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     9
# Train_cost  = 0.6932 | Test_cost  = 0.6933 | Train_score = 0.4921 | Test_score = 0.5000 |
# ==> EarlyStop patience =  4 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 10 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 278.98it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 689.78it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6934 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5132 │ 0.5000 │ │ green │  0.5304  │
# │ Subset Accuracy  │ 0.3519 │ 0.0059 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4292 │ 0.6653 │ └───────┴──────────┘
# │ Macro F1         │ 0.4069 │ 0.6649 │
# │ Overall Accuracy │ 0.4868 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch    10
# Train_cost  = 0.6932 | Test_cost  = 0.6934 | Train_score = 0.4868 | Test_score = 0.5000 |
# ==> EarlyStop patience =  5 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 11 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 298.54it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 718.23it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6935 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5088 │ 0.5110 │ │ green │  0.5084  │
# │ Subset Accuracy  │ 0.3762 │ 0.1064 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4382 │ 0.6304 │ └───────┴──────────┘
# │ Macro F1         │ 0.3778 │ 0.6298 │
# │ Overall Accuracy │ 0.4912 │ 0.4890 │
# └──────────────────┴────────┴────────┘
# Epoch    11
# Train_cost  = 0.6932 | Test_cost  = 0.6935 | Train_score = 0.4912 | Test_score = 0.4890 |
# ==> EarlyStop patience =  6 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 12 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 293.22it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 588.01it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6935 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5046 │ 0.5207 │ │ green │  0.4890  │
# │ Subset Accuracy  │ 0.3965 │ 0.1605 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4483 │ 0.6052 │ └───────┴──────────┘
# │ Macro F1         │ 0.3549 │ 0.6008 │
# │ Overall Accuracy │ 0.4954 │ 0.4793 │
# └──────────────────┴────────┴────────┘
# Epoch    12
# Train_cost  = 0.6932 | Test_cost  = 0.6935 | Train_score = 0.4954 | Test_score = 0.4793 |
# ==> EarlyStop patience =  7 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 13 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 274.50it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 730.99it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5035 │ 0.5194 │ │ green │  0.4916  │
# │ Subset Accuracy  │ 0.4178 │ 0.1833 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4577 │ 0.5996 │ └───────┴──────────┘
# │ Macro F1         │ 0.3316 │ 0.5936 │
# │ Overall Accuracy │ 0.4965 │ 0.4806 │
# └──────────────────┴────────┴────────┘
# Epoch    13
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.4965 | Test_score = 0.4806 |
# ==> EarlyStop patience =  8 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 14 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 274.85it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 767.86it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5037 │ 0.5207 │ │ green │  0.4890  │
# │ Subset Accuracy  │ 0.4431 │ 0.1976 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4705 │ 0.5937 │ └───────┴──────────┘
# │ Macro F1         │ 0.3299 │ 0.5859 │
# │ Overall Accuracy │ 0.4963 │ 0.4793 │
# └──────────────────┴────────┴────────┘
# Epoch    14
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.4963 | Test_score = 0.4793 |
# ==> EarlyStop patience =  9 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 15 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 272.60it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 736.56it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5021 │ 0.5215 │ │ green │  0.4873  │
# │ Subset Accuracy  │ 0.4553 │ 0.2120 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4776 │ 0.5882 │ └───────┴──────────┘
# │ Macro F1         │ 0.3254 │ 0.5785 │
# │ Overall Accuracy │ 0.4979 │ 0.4785 │
# └──────────────────┴────────┴────────┘
# Epoch    15
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.4979 | Test_score = 0.4785 |
# ==> EarlyStop patience = 10 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 16 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 269.25it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 691.48it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5010 │ 0.5182 │ │ green │  0.4941  │
# │ Subset Accuracy  │ 0.4709 │ 0.2382 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4859 │ 0.5834 │ └───────┴──────────┘
# │ Macro F1         │ 0.3282 │ 0.5710 │
# │ Overall Accuracy │ 0.4990 │ 0.4818 │
# └──────────────────┴────────┴────────┘
# Epoch    16
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.4990 | Test_score = 0.4818 |
# ==> EarlyStop patience = 11 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 17 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 278.80it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 666.17it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5003 │ 0.5211 │ │ green │  0.4882  │
# │ Subset Accuracy  │ 0.4801 │ 0.2483 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4907 │ 0.5765 │ └───────┴──────────┘
# │ Macro F1         │ 0.3301 │ 0.5614 │
# │ Overall Accuracy │ 0.4997 │ 0.4789 │
# └──────────────────┴────────┴────────┘
# Epoch    17
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.4997 | Test_score = 0.4789 |
# ==> EarlyStop patience = 12 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 18 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 280.37it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 560.16it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5001 │ 0.5173 │ │ green │  0.4958  │
# │ Subset Accuracy  │ 0.4873 │ 0.2644 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4943 │ 0.5754 │ └───────┴──────────┘
# │ Macro F1         │ 0.3314 │ 0.5588 │
# │ Overall Accuracy │ 0.4999 │ 0.4827 │
# └──────────────────┴────────┴────────┘
# Epoch    18
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.4999 | Test_score = 0.4827 |
# ==> EarlyStop patience = 13 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 19 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 265.88it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 711.69it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4986 │ 0.5160 │ │ green │  0.4983  │
# │ Subset Accuracy  │ 0.4934 │ 0.2686 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4981 │ 0.5754 │ └───────┴──────────┘
# │ Macro F1         │ 0.3334 │ 0.5586 │
# │ Overall Accuracy │ 0.5014 │ 0.4840 │
# └──────────────────┴────────┴────────┘
# Epoch    19
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5014 | Test_score = 0.4840 |
# ==> EarlyStop patience = 14 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 20 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 272.20it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 585.80it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4984 │ 0.5148 │ │ green │  0.5008  │
# │ Subset Accuracy  │ 0.4967 │ 0.2720 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.4999 │ 0.5757 │ └───────┴──────────┘
# │ Macro F1         │ 0.3343 │ 0.5587 │
# │ Overall Accuracy │ 0.5016 │ 0.4852 │
# └──────────────────┴────────┴────────┘
# Epoch    20
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5016 | Test_score = 0.4852 |
# ==> EarlyStop patience = 15 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 21 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 249.88it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 647.33it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4982 │ 0.5148 │ │ green │  0.5008  │
# │ Subset Accuracy  │ 0.4983 │ 0.2728 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5006 │ 0.5754 │ └───────┴──────────┘
# │ Macro F1         │ 0.3343 │ 0.5583 │
# │ Overall Accuracy │ 0.5018 │ 0.4852 │
# └──────────────────┴────────┴────────┘
# Epoch    21
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5018 | Test_score = 0.4852 |
# ==> EarlyStop patience = 16 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 22 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 269.56it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 696.59it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4974 │ 0.5148 │ │ green │  0.5008  │
# │ Subset Accuracy  │ 0.5002 │ 0.2728 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5017 │ 0.5754 │ └───────┴──────────┘
# │ Macro F1         │ 0.3349 │ 0.5583 │
# │ Overall Accuracy │ 0.5026 │ 0.4852 │
# └──────────────────┴────────┴────────┘
# Epoch    22
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5026 | Test_score = 0.4852 |
# ==> EarlyStop patience = 17 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 23 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 275.62it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 725.01it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5156 │ │ green │  0.4992  │
# │ Subset Accuracy  │ 0.5016 │ 0.2711 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5025 │ 0.5750 │ └───────┴──────────┘
# │ Macro F1         │ 0.3350 │ 0.5578 │
# │ Overall Accuracy │ 0.5029 │ 0.4844 │
# └──────────────────┴────────┴────────┘
# Epoch    23
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4844 |
# ==> EarlyStop patience = 18 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 24 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 272.80it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 627.10it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4972 │ 0.5152 │ │ green │  0.5000  │
# │ Subset Accuracy  │ 0.5019 │ 0.2703 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5026 │ 0.5758 │ └───────┴──────────┘
# │ Macro F1         │ 0.3351 │ 0.5590 │
# │ Overall Accuracy │ 0.5028 │ 0.4848 │
# └──────────────────┴────────┴────────┘
# Epoch    24
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5028 | Test_score = 0.4848 |
# ==> EarlyStop patience = 19 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 25 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 288.23it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 658.46it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5165 │ │ green │  0.4975  │
# │ Subset Accuracy  │ 0.5021 │ 0.2669 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5027 │ 0.5755 │ └───────┴──────────┘
# │ Macro F1         │ 0.3351 │ 0.5588 │
# │ Overall Accuracy │ 0.5029 │ 0.4835 │
# └──────────────────┴────────┴────────┘
# Epoch    25
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4835 |
# ==> EarlyStop patience = 20 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 26 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 279.67it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 709.66it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5169 │ │ green │  0.4966  │
# │ Subset Accuracy  │ 0.5021 │ 0.2652 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5029 │ 0.5756 │ └───────┴──────────┘
# │ Macro F1         │ 0.3355 │ 0.5591 │
# │ Overall Accuracy │ 0.5029 │ 0.4831 │
# └──────────────────┴────────┴────────┘
# Epoch    26
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4831 |
# ==> EarlyStop patience = 21 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 27 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 269.91it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 655.50it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5173 │ │ green │  0.4958  │
# │ Subset Accuracy  │ 0.5021 │ 0.2627 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5029 │ 0.5760 │ └───────┴──────────┘
# │ Macro F1         │ 0.3355 │ 0.5597 │
# │ Overall Accuracy │ 0.5029 │ 0.4827 │
# └──────────────────┴────────┴────────┘
# Epoch    27
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4827 |
# ==> EarlyStop patience = 22 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 28 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 279.56it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 678.47it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5186 │ │ green │  0.4932  │
# │ Subset Accuracy  │ 0.5019 │ 0.2601 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5029 │ 0.5754 │ └───────┴──────────┘
# │ Macro F1         │ 0.3356 │ 0.5591 │
# │ Overall Accuracy │ 0.5029 │ 0.4814 │
# └──────────────────┴────────┴────────┘
# Epoch    28
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4814 |
# ==> EarlyStop patience = 23 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 29 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 288.72it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 651.25it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5186 │ │ green │  0.4932  │
# │ Subset Accuracy  │ 0.5021 │ 0.2584 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5030 │ 0.5760 │ └───────┴──────────┘
# │ Macro F1         │ 0.3356 │ 0.5600 │
# │ Overall Accuracy │ 0.5029 │ 0.4814 │
# └──────────────────┴────────┴────────┘
# Epoch    29
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4814 |
# ==> EarlyStop patience = 24 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 30 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 261.36it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 638.47it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5198 │ │ green │  0.4907  │
# │ Subset Accuracy  │ 0.5021 │ 0.2551 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5032 │ 0.5757 │ └───────┴──────────┘
# │ Macro F1         │ 0.3360 │ 0.5599 │
# │ Overall Accuracy │ 0.5029 │ 0.4802 │
# └──────────────────┴────────┴────────┘
# Epoch    30
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4802 |
# ==> EarlyStop patience = 25 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 31 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 266.32it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 684.58it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5203 │ │ green │  0.4899  │
# │ Subset Accuracy  │ 0.5021 │ 0.2534 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5032 │ 0.5758 │ └───────┴──────────┘
# │ Macro F1         │ 0.3360 │ 0.5601 │
# │ Overall Accuracy │ 0.5029 │ 0.4797 │
# └──────────────────┴────────┴────────┘
# Epoch    31
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4797 |
# ==> EarlyStop patience = 26 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 32 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 278.85it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 584.64it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5203 │ │ green │  0.4899  │
# │ Subset Accuracy  │ 0.5021 │ 0.2500 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5032 │ 0.5769 │ └───────┴──────────┘
# │ Macro F1         │ 0.3360 │ 0.5619 │
# │ Overall Accuracy │ 0.5029 │ 0.4797 │
# └──────────────────┴────────┴────────┘
# Epoch    32
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4797 |
# ==> EarlyStop patience = 27 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 33 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 274.62it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 652.20it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5224 │ │ green │  0.4856  │
# │ Subset Accuracy  │ 0.5021 │ 0.2441 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5032 │ 0.5765 │ └───────┴──────────┘
# │ Macro F1         │ 0.3360 │ 0.5617 │
# │ Overall Accuracy │ 0.5029 │ 0.4776 │
# └──────────────────┴────────┴────────┘
# Epoch    33
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4776 |
# ==> EarlyStop patience = 28 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 34 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 261.17it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 668.10it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4971 │ 0.5241 │ │ green │  0.4823  │
# │ Subset Accuracy  │ 0.5021 │ 0.2390 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5032 │ 0.5763 │ └───────┴──────────┘
# │ Macro F1         │ 0.3360 │ 0.5618 │
# │ Overall Accuracy │ 0.5029 │ 0.4759 │
# └──────────────────┴────────┴────────┘
# Epoch    34
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5029 | Test_score = 0.4759 |
# ==> EarlyStop patience = 29 | Best test_score: 0.5308
# ─────────────────────────────────────────────────── 🚀 EPOCH 35 ───────────────────────────────────────────────────
# train: 100%|██████████| 181/181 [00:00<00:00, 267.03it/s]
# test: 100%|██████████| 37/37 [00:00<00:00, 595.07it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6936 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4973 │ 0.5253 │ │ green │  0.4797  │
# │ Subset Accuracy  │ 0.5019 │ 0.2348 │ │  red  │  0.4696  │
# │ Micro F1         │ 0.5031 │ 0.5763 │ └───────┴──────────┘
# │ Macro F1         │ 0.3360 │ 0.5620 │
# │ Overall Accuracy │ 0.5027 │ 0.4747 │
# └──────────────────┴────────┴────────┘
# Epoch    35
# Train_cost  = 0.6932 | Test_cost  = 0.6936 | Train_score = 0.5027 | Test_score = 0.4747 |
# ==> EarlyStop patience = 30 | Best test_score: 0.5308
# ==> Execute Early Stopping at epoch: 35 | Best test_score: 0.5308
# ==> Best model is saved at timeseris/multi-label-clasification/lstm/microsoft_stock_data/
# ⏹️ Training dihentikan oleh early stopping.

# %% [markdown]
# # Evaluate

# %%
from evaluate import evaluate_multi_label

hsl = evaluate_multi_label(model, test_loader, target_cols,criterion, device, config.threshold)
# Out:
#        📊 Evaluasi Model         🎯 Per-Label Accuracy
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━┳━━━━━━━━━┓
# ┃ Metrik              ┃  Nilai ┃ ┃  Label  ┃ Akurasi ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━╇━━━━━━━━━┩
# │ 🔹 Overall Accuracy │ 0.5308 │ │ y_green │ 0.5304  │
# │ ✅ Subset  Accuracy │ 0.4932 │ │  y_red  │ 0.5312  │
# │ 💥 Loss (avg)       │ 0.6927 │ └─────────┴─────────┘
# │ 📉 Hamming Loss     │ 0.4692 │
# │ ⚖️  Micro F1-score   │ 0.5478 │
# │ 📈 Macro F1-score   │ 0.4163 │
# └─────────────────────┴────────┘

# %%
hsl = hsl['df']
b = hsl[hsl['Benar (%)'] == 100]
b.head(300)
# Out:
#          Target    Prediksi  Benar (%)
# 0    [1.0, 0.0]  [1.0, 0.0]      100.0
# 2    [1.0, 0.0]  [1.0, 0.0]      100.0
# 6    [1.0, 0.0]  [1.0, 0.0]      100.0
# 9    [1.0, 0.0]  [1.0, 0.0]      100.0
# 11   [1.0, 0.0]  [1.0, 0.0]      100.0
# ..          ...         ...        ...
# 572  [1.0, 0.0]  [1.0, 0.0]      100.0
# 573  [1.0, 0.0]  [1.0, 0.0]      100.0
# 575  [1.0, 0.0]  [1.0, 0.0]      100.0
# 576  [1.0, 0.0]  [1.0, 0.0]      100.0
# 577  [1.0, 0.0]  [1.0, 0.0]      100.0
#
# [300 rows x 3 columns]

# %%
b.shape
# Out:
# (584, 3)

# %%
s = hsl[hsl['Benar (%)'] == 0]
s.head(300)
# Out:
#          Target    Prediksi  Benar (%)
# 1    [0.0, 1.0]  [1.0, 0.0]        0.0
# 3    [0.0, 1.0]  [1.0, 0.0]        0.0
# 4    [0.0, 1.0]  [1.0, 0.0]        0.0
# 5    [0.0, 1.0]  [1.0, 0.0]        0.0
# 7    [0.0, 1.0]  [1.0, 0.0]        0.0
# ..          ...         ...        ...
# 621  [0.0, 1.0]  [1.0, 0.0]        0.0
# 622  [0.0, 1.0]  [1.0, 0.0]        0.0
# 624  [0.0, 1.0]  [1.0, 0.0]        0.0
# 625  [0.0, 1.0]  [1.0, 0.0]        0.0
# 627  [0.0, 1.0]  [1.0, 0.0]        0.0
#
# [300 rows x 3 columns]

# %%
s.shape
# Out:
# (511, 3)
