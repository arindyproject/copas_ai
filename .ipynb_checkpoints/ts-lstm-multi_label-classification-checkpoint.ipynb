# %% [markdown]
# #                                  timeseris Multi Label Clasification - LSTM

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import os
import numpy as np

# %%
file_name = "microsoft_stock_data"
root_folder = f'timeseris/multi-label-clasification/lstm/{file_name}/' 
os.makedirs(root_folder, exist_ok=True)

df = pd.read_csv('sample_data/'+file_name+'.csv')

df.head()
# Out:
#         Date     Close      High       Low      Open    Volume
# 0  3/26/1986  0.057906  0.058437  0.055781  0.056312  22752000
# 1  3/27/1986  0.058969  0.058969  0.057906  0.057906  16848000
# 2  3/31/1986  0.058437  0.058969  0.057375  0.058969  12873600
# 3   4/1/1986  0.057906  0.058437  0.057906  0.058437  11088000
# 4   4/2/1986  0.058437  0.059500  0.057906  0.057906  27014400

# %% [markdown]
# #### Pilih tahun mulai data

# %%
# Pastikan kolom Date dalam format datetime
df['Date'] = pd.to_datetime(df['Date'])

# Filter data mulai dari tahun 2000
df = df[df['Date'] >= '1998-01-01']

# (Opsional) urutkan berdasarkan tanggal
df = df.sort_values('Date').reset_index(drop=True)
df.head()
# Out:
#         Date      Close       High       Low       Open    Volume
# 0 1998-01-02  10.031051  10.059738  9.906738   9.916301  39748000
# 1 1998-01-05   9.973679  10.222303  9.782429  10.040616  80377600
# 2 1998-01-06  10.031051  10.174488  9.887613   9.925863  67834400
# 3 1998-01-07   9.911519  10.035831  9.753738   9.935425  61492800
# 4 1998-01-08   9.983242  10.107554  9.753742   9.839805  77619200

# %% [markdown]
# #### tambahkan status green, red, dan netral || DayName

# %%
# === Tambahkan kolom nama hari ===
df['Day'] =  df['Date'].dt.day_name()  # bahasa Inggris

# Buat kondisi
conditions = [
    df['Close'] > df['Open'],
    df['Close'] < df['Open'],
    df['Close'] == df['Open']
]
choices = ['green', 'red', 'red']

df['Status'] = np.select(conditions, choices)
df.head()
# Out:
#         Date      Close       High       Low       Open    Volume        Day  \
# 0 1998-01-02  10.031051  10.059738  9.906738   9.916301  39748000     Friday
# 1 1998-01-05   9.973679  10.222303  9.782429  10.040616  80377600     Monday
# 2 1998-01-06  10.031051  10.174488  9.887613   9.925863  67834400    Tuesday
# 3 1998-01-07   9.911519  10.035831  9.753738   9.935425  61492800  Wednesday
# 4 1998-01-08   9.983242  10.107554  9.753742   9.839805  77619200   Thursday
#
#   Status
# 0  green
# 1    red
# 2  green
# 3    red
# 4  green

# %% [markdown]
# #### Chart Donat

# %%
import matplotlib.pyplot as plt

# Contoh: df sudah punya kolom Status
# (kalau belum, bisa pakai kode sebelumnya untuk menambahkannya)

# Hitung jumlah masing-masing status
status_counts = df['Status'].value_counts()

# Warna donat
colors = {
    'green': '#2ecc71',   # hijau
    'red': '#e74c3c',     # merah
    'neutral': '#95a5a6'  # abu-abu
}

# Buat donut chart
fig, ax = plt.subplots(figsize=(6, 6))
wedges, texts, autotexts = ax.pie(
    status_counts,
    labels=status_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=[colors[k] for k in status_counts.index],
    wedgeprops=dict(width=0.4)  # buat efek donut
)

# Tambahkan teks di tengah
ax.text(0, 0, 'Status\nCandlestick', ha='center', va='center', fontsize=12, weight='bold')

plt.title('Distribusi Candle: Green, Red, dan Neutral', fontsize=14)
plt.show()

# %%
status_counts
# Out:
# Status
# green    3521
# red      3471
# Name: count, dtype: int64

# %% [markdown]
# #### LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#labeling
df['label_Day']            = le.fit_transform(df['Day'])
df.head()
# Out:
#         Date      Close       High       Low       Open    Volume        Day  \
# 0 1998-01-02  10.031051  10.059738  9.906738   9.916301  39748000     Friday
# 1 1998-01-05   9.973679  10.222303  9.782429  10.040616  80377600     Monday
# 2 1998-01-06  10.031051  10.174488  9.887613   9.925863  67834400    Tuesday
# 3 1998-01-07   9.911519  10.035831  9.753738   9.935425  61492800  Wednesday
# 4 1998-01-08   9.983242  10.107554  9.753742   9.839805  77619200   Thursday
#
#   Status  label_Day
# 0  green          0
# 1    red          1
# 2  green          3
# 3    red          4
# 4  green          2

# %% [markdown]
# #### Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib

# Contoh: buat dan fit scaler
scaler = MinMaxScaler()
cols = [
    'label_Day',
    'Close', 
    'High', 
    'Low',
    'Open',
    'Volume', 
]

# Dictionary untuk menyimpan hasil transformasi
scaled_data = {}

# Loop untuk setiap kolom
for col in cols:
    scaler = MinMaxScaler()
    df[[col]] = scaler.fit_transform(df[[col]])  # scaling per kolom
    joblib.dump(scaler, os.path.join(root_folder, f'scaler_{col}.pkl'))
    scaled_data[col] = scaler
    print(f"✅ Scaler for '{col}' saved as scaler_{col}.pkl")

print("\nAll individual scalers saved successfully!")
# Out:
# ✅ Scaler for 'label_Day' saved as scaler_label_Day.pkl
# ✅ Scaler for 'Close' saved as scaler_Close.pkl
# ✅ Scaler for 'High' saved as scaler_High.pkl
# ✅ Scaler for 'Low' saved as scaler_Low.pkl
# ✅ Scaler for 'Open' saved as scaler_Open.pkl
# ✅ Scaler for 'Volume' saved as scaler_Volume.pkl
#
# All individual scalers saved successfully!

# %%
df.head()
# Out:
#         Date     Close      High       Low      Open    Volume        Day  \
# 0 1998-01-02  0.000601  0.000211  0.000752  0.000702  0.055804     Friday
# 1 1998-01-05  0.000492  0.000509  0.000513  0.000930  0.125389     Monday
# 2 1998-01-06  0.000601  0.000421  0.000715  0.000720  0.103907    Tuesday
# 3 1998-01-07  0.000373  0.000167  0.000458  0.000737  0.093046  Wednesday
# 4 1998-01-08  0.000510  0.000299  0.000458  0.000562  0.120665   Thursday
#
#   Status  label_Day
# 0  green       0.00
# 1    red       0.25
# 2  green       0.75
# 3    red       1.00
# 4  green       0.50

# %% [markdown]
# #### Mapping label

# %%
import json
mapping_dicts = {}

cols = [
    'Day',
]

for col in cols:
    label_col = f"label_{col}"
    mapping_dicts[col] = dict(zip(df[col], df[label_col]))


with open(root_folder + 'label_mappings.json', 'w') as f:
    json.dump(mapping_dicts, f, indent=2)

rows = []
for col, mapping in mapping_dicts.items():
    for k, v in mapping.items():
        rows.append({'feature': col, 'original_value': k, 'label_value': v})

mapping_table = pd.DataFrame(rows)
print(mapping_table)
# Out:
#   feature original_value  label_value
# 0     Day         Friday         0.00
# 1     Day         Monday         0.25
# 2     Day        Tuesday         0.75
# 3     Day      Wednesday         1.00
# 4     Day       Thursday         0.50

# %% [markdown]
# #### Select Kolom To Trian

# %%
col_target = 'Status'
cols = [
    'Date',
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    'Volume',
    col_target
]
df = df[cols].copy()
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 1998-01-02       0.00  0.000601  0.000211  0.000752  0.000702  0.055804
# 1 1998-01-05       0.25  0.000492  0.000509  0.000513  0.000930  0.125389
# 2 1998-01-06       0.75  0.000601  0.000421  0.000715  0.000720  0.103907
# 3 1998-01-07       1.00  0.000373  0.000167  0.000458  0.000737  0.093046
# 4 1998-01-08       0.50  0.000510  0.000299  0.000458  0.000562  0.120665
#
#   Status
# 0  green
# 1    red
# 2  green
# 3    red
# 4  green

# %% [markdown]
# #### Tentukan target -> one-hot encoding

# %%
y_counts = df[col_target].value_counts(normalize=True)
labels = list(y_counts.index)

df_y_encoded = pd.get_dummies(df[col_target], prefix='y')

# Pastikan semua nama kolom lowercase dan spasi → underscore
df_y_encoded.columns = (
    df_y_encoded.columns.str.lower()
                        .str.replace(' ', '_')
)

# Gabungkan ke DataFrame utama
df = pd.concat([df.drop(col_target, axis=1), df_y_encoded.astype(int)], axis=1)
df.head()
# Out:
#         Date  label_Day     Close      High       Low      Open    Volume  \
# 0 1998-01-02       0.00  0.000601  0.000211  0.000752  0.000702  0.055804
# 1 1998-01-05       0.25  0.000492  0.000509  0.000513  0.000930  0.125389
# 2 1998-01-06       0.75  0.000601  0.000421  0.000715  0.000720  0.103907
# 3 1998-01-07       1.00  0.000373  0.000167  0.000458  0.000737  0.093046
# 4 1998-01-08       0.50  0.000510  0.000299  0.000458  0.000562  0.120665
#
#    y_green  y_red
# 0        1      0
# 1        0      1
# 2        1      0
# 3        0      1
# 4        1      0

# %% [markdown]
# # Data Load To Train

# %% [markdown]
# #### select Future to traian

# %%
feature_cols = [
    'label_Day', 
    'Close', 
    'High',
    'Low',
    'Open',
    #'Volume',
]
target_cols = [col for col in df.columns if col.startswith('y_')]

# %% [markdown]
# #### Split data

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

tgl_pembatas = '2020-01-01'
X_train = df[df['Date'] <= tgl_pembatas]
X_test  = df[df['Date'] > tgl_pembatas]
print(f'Train : f{X_train.shape}')
print(f'Test  : f{X_test.shape}')
# Out:
# Train : f(5535, 9)
# Test  : f(1457, 9)

# %% [markdown]
# #### DataLoader

# %%
from data_set import MultiLabelTimeSeriesDataset
seq_length = 20
slide      = 1
# Buat dataset dengan class kamu
train_dataset = MultiLabelTimeSeriesDataset(X_train,seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)
test_dataset  = MultiLabelTimeSeriesDataset(X_test, seq_length=seq_length, slide=slide, feature_cols=feature_cols, target_cols=target_cols, normalize=False)

# Buat DataLoader
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Cek contoh batch
for X, y in train_loader:
    print("X shape:", X.shape)
    print("y shape:", y.shape)
    print(X[:3])  # contoh fitur
    print(y[:3])  # contoh label
    break
# Out:
# X shape: torch.Size([32, 20, 5])
# y shape: torch.Size([32, 2])
# tensor([[[0.5000, 0.0181, 0.0176, 0.0176, 0.0176],
#          [0.0000, 0.0172, 0.0169, 0.0175, 0.0174],
#          [0.2500, 0.0171, 0.0168, 0.0173, 0.0174],
#          [0.7500, 0.0182, 0.0171, 0.0176, 0.0169],
#          [1.0000, 0.0184, 0.0174, 0.0182, 0.0177],
#          [0.5000, 0.0179, 0.0177, 0.0183, 0.0184],
#          [0.0000, 0.0189, 0.0180, 0.0182, 0.0175],
#          [0.2500, 0.0198, 0.0187, 0.0196, 0.0190],
#          [0.7500, 0.0204, 0.0195, 0.0201, 0.0193],
#          [1.0000, 0.0210, 0.0199, 0.0210, 0.0201],
#          [0.5000, 0.0204, 0.0201, 0.0209, 0.0203],
#          [0.0000, 0.0198, 0.0189, 0.0201, 0.0194],
#          [0.7500, 0.0193, 0.0183, 0.0193, 0.0185],
#          [1.0000, 0.0201, 0.0189, 0.0199, 0.0192],
#          [0.5000, 0.0204, 0.0199, 0.0205, 0.0197],
#          [0.0000, 0.0197, 0.0192, 0.0198, 0.0197],
#          [0.2500, 0.0199, 0.0188, 0.0195, 0.0189],
#          [0.7500, 0.0201, 0.0192, 0.0203, 0.0196],
#          [1.0000, 0.0208, 0.0201, 0.0204, 0.0199],
#          [0.5000, 0.0215, 0.0204, 0.0210, 0.0207]],
#
#         [[1.0000, 0.1051, 0.1011, 0.1051, 0.1008],
#          [0.5000, 0.1062, 0.1024, 0.1065, 0.1022],
#          [0.0000, 0.1079, 0.1044, 0.1076, 0.1034],
#          [0.2500, 0.1089, 0.1047, 0.1089, 0.1044],
#          [0.7500, 0.1088, 0.1046, 0.1088, 0.1049],
#          [1.0000, 0.1098, 0.1057, 0.1102, 0.1055],
#          [0.5000, 0.1104, 0.1062, 0.1099, 0.1067],
#          [0.0000, 0.1097, 0.1061, 0.1097, 0.1055],
#          [0.2500, 0.1093, 0.1052, 0.1096, 0.1056],
#          [0.7500, 0.1104, 0.1062, 0.1103, 0.1060],
#          [1.0000, 0.1101, 0.1063, 0.1108, 0.1069],
#          [0.5000, 0.1086, 0.1064, 0.1082, 0.1060],
#          [0.0000, 0.1084, 0.1045, 0.1086, 0.1042],
#          [0.2500, 0.1078, 0.1047, 0.1084, 0.1052],
#          [0.7500, 0.1076, 0.1047, 0.1085, 0.1049],
#          [1.0000, 0.1070, 0.1032, 0.1067, 0.1040],
#          [0.5000, 0.1068, 0.1030, 0.1074, 0.1033],
#          [0.0000, 0.1077, 0.1041, 0.1081, 0.1037],
#          [0.2500, 0.1073, 0.1038, 0.1081, 0.1044],
#          [0.7500, 0.1079, 0.1042, 0.1072, 0.1032]],
#
#         [[0.0000, 0.1504, 0.1482, 0.1485, 0.1484],
#          [0.2500, 0.1464, 0.1456, 0.1471, 0.1462],
#          [0.7500, 0.1490, 0.1437, 0.1465, 0.1409],
#          [1.0000, 0.1464, 0.1435, 0.1472, 0.1439],
#          [0.5000, 0.1474, 0.1431, 0.1459, 0.1405],
#          [0.0000, 0.1493, 0.1439, 0.1467, 0.1411],
#          [0.2500, 0.1512, 0.1461, 0.1506, 0.1442],
#          [0.7500, 0.1504, 0.1452, 0.1505, 0.1454],
#          [1.0000, 0.1524, 0.1466, 0.1505, 0.1457],
#          [0.5000, 0.1541, 0.1482, 0.1540, 0.1481],
#          [0.0000, 0.1538, 0.1481, 0.1540, 0.1487],
#          [0.2500, 0.1543, 0.1495, 0.1545, 0.1489],
#          [0.7500, 0.1531, 0.1481, 0.1528, 0.1477],
#          [1.0000, 0.1535, 0.1480, 0.1540, 0.1487],
#          [0.5000, 0.1518, 0.1483, 0.1526, 0.1476],
#          [0.0000, 0.1521, 0.1472, 0.1529, 0.1464],
#          [0.2500, 0.1543, 0.1491, 0.1543, 0.1481],
#          [0.7500, 0.1542, 0.1493, 0.1551, 0.1492],
#          [1.0000, 0.1562, 0.1503, 0.1535, 0.1476],
#          [0.5000, 0.1556, 0.1507, 0.1544, 0.1510]]])
# tensor([[1., 0.],
#         [1., 0.],
#         [0., 1.]])

# %% [markdown]
# # Config

# %%
from jcopdl.callback import Callback, set_config
config = set_config({
    "labels"         : labels,
    "threshold"      : 0.5,
    "input_size"     : len(test_dataset[0][0][0]),
    "hidden_size"    : 8,
    "num_layers"     : 2,
    "num_classes"    : len(labels),
    "dropout"        : 0.0,
    "bidirectional"  : True,
    "early_stop_patience" : 30,
    "col_target"     : col_target,
    "feature_cols"   : feature_cols
})
config
# Out:
# Config(bidirectional=True, col_target=Status, dropout=0.0, early_stop_patience=30, feature_cols=['label_Day', 'Close', 'High', 'Low', 'Open'], hidden_size=8, input_size=5, labels=['green', 'red'], num_classes=2, num_layers=2, threshold=0.5)

# %% [markdown]
# # MCOC

# %% [markdown]
# #### Model - Criterion - Optimizer - Callback

# %%
from class_lib import LSTM_MultiLabelClassifier
from torch import optim, nn
from jcopdl.callback import Callback
import torch.optim as optim

#Model input_size, hidden_size, num_layers, num_classes, dropout=0.2, bidirectional=False
model = LSTM_MultiLabelClassifier(
    input_size=config.input_size, 
    hidden_size=config.hidden_size, 
    num_layers=config.num_layers, 
    num_classes=config.num_classes, 
    dropout=config.dropout, 
    bidirectional=config.bidirectional
).to(device)

#Criterion
criterion =nn.BCELoss()

# --- Pilihan Optimizer ---
# AdamW
optimizer_adamw = optim.AdamW(model.parameters(), lr=0.001)
# Adam
optimizer_adam = optim.Adam(model.parameters(), lr=0.001)
# SGD (Stochastic Gradient Descent)
optimizer_sgd = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# RMSprop
optimizer_rmsprop = optim.RMSprop(model.parameters(), lr=0.001, momentum=0.9)
# Adagrad
optimizer_adagrad = optim.Adagrad(model.parameters(), lr=0.01)
# Adadelta
optimizer_adadelta = optim.Adadelta(model.parameters(), lr=0.1)
# ASGD (Averaged SGD)
optimizer_asgd = optim.ASGD(model.parameters(), lr=0.01)

# --- Contoh cara memilih salah satu ---
optim = optimizer_sgd  # misalnya kita pakai RAdam

#Callback
callback = Callback(model, config, outdir=root_folder,early_stop_patience=config.early_stop_patience)

# %% [markdown]
# # Training

# %%
from train_and_evaluate import train_and_evaluate_multi_label

train_and_evaluate_multi_label(
    model=model,
    train_dataset=train_dataset,
    test_dataset=test_dataset,
    train_loader=train_loader,
    test_loader=test_loader,
    criterion=criterion,
    optim=optim,
    config=config,
    device=device,
    labels=labels,          
    callback=callback
)
# Out:
# ─────────────────────────────────────────────────── 🚀 EPOCH 1 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 282.58it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 502.18it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6975 │ 0.6971 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     1
# Train_cost  = 0.6975 | Test_cost  = 0.6971 | Train_score = 0.5000 | Test_score = 0.5000 |
# ─────────────────────────────────────────────────── 🚀 EPOCH 2 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 275.51it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 661.96it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6957 │ 0.6958 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     2
# Train_cost  = 0.6957 | Test_cost  = 0.6958 | Train_score = 0.5000 | Test_score = 0.5000 |
# ==> EarlyStop patience =  1 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 3 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 280.32it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 702.17it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6946 │ 0.6951 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     3
# Train_cost  = 0.6946 | Test_cost  = 0.6951 | Train_score = 0.5000 | Test_score = 0.5000 |
# ==> EarlyStop patience =  2 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 4 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 284.07it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 702.08it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6940 │ 0.6946 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     4
# Train_cost  = 0.6940 | Test_cost  = 0.6946 | Train_score = 0.5000 | Test_score = 0.5000 |
# ==> EarlyStop patience =  3 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 5 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 281.71it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 660.00it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6937 │ 0.6944 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     5
# Train_cost  = 0.6937 | Test_cost  = 0.6944 | Train_score = 0.5000 | Test_score = 0.5000 |
# ==> EarlyStop patience =  4 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 6 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 250.54it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 642.22it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6935 │ 0.6944 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     6
# Train_cost  = 0.6935 | Test_cost  = 0.6944 | Train_score = 0.5000 | Test_score = 0.5000 |
# ==> EarlyStop patience =  5 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 7 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 259.16it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 653.40it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6933 │ 0.6942 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     7
# Train_cost  = 0.6933 | Test_cost  = 0.6942 | Train_score = 0.5000 | Test_score = 0.5000 |
# ==> EarlyStop patience =  6 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 8 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 286.43it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 725.72it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6933 │ 0.6942 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5000 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.0000 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.0000 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.0000 │ 0.0000 │
# │ Overall Accuracy │ 0.5000 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     8
# Train_cost  = 0.6933 | Test_cost  = 0.6942 | Train_score = 0.5000 | Test_score = 0.5000 |
# ==> EarlyStop patience =  7 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 9 ────────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 272.32it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 699.56it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.5006 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.1206 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.1941 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.1614 │ 0.0000 │
# │ Overall Accuracy │ 0.4994 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch     9
# Train_cost  = 0.6932 | Test_cost  = 0.6941 | Train_score = 0.4994 | Test_score = 0.5000 |
# ==> EarlyStop patience =  8 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 10 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 276.09it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 710.74it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4981 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.1942 │ 0.0000 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.2805 │ 0.0000 │ └───────┴──────────┘
# │ Macro F1         │ 0.2184 │ 0.0000 │
# │ Overall Accuracy │ 0.5019 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch    10
# Train_cost  = 0.6932 | Test_cost  = 0.6941 | Train_score = 0.5019 | Test_score = 0.5000 |
# ==> EarlyStop patience =  9 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 11 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 274.94it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 665.80it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4983 │ 0.5000 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.3793 │ 0.0028 │ │  red  │  0.5310  │
# │ Micro F1         │ 0.4322 │ 0.0055 │ └───────┴──────────┘
# │ Macro F1         │ 0.3011 │ 0.0059 │
# │ Overall Accuracy │ 0.5017 │ 0.5000 │
# └──────────────────┴────────┴────────┘
# Epoch    11
# Train_cost  = 0.6932 | Test_cost  = 0.6940 | Train_score = 0.5017 | Test_score = 0.5000 |
# ==> EarlyStop patience = 10 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 12 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 279.03it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 595.98it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4956 │ 0.5216 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.4963 │ 0.3236 │ │  red  │  0.4878  │
# │ Micro F1         │ 0.5003 │ 0.3829 │ └───────┴──────────┘
# │ Macro F1         │ 0.3334 │ 0.2791 │
# │ Overall Accuracy │ 0.5044 │ 0.4784 │
# └──────────────────┴────────┴────────┘
# Epoch    12
# Train_cost  = 0.6932 | Test_cost  = 0.6940 | Train_score = 0.5044 | Test_score = 0.4784 |
# ==> EarlyStop patience = 11 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 13 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 280.65it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 711.42it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4948 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5044 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5048 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3356 │ 0.3193 │
# │ Overall Accuracy │ 0.5052 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    13
# Train_cost  = 0.6932 | Test_cost  = 0.6941 | Train_score = 0.5052 | Test_score = 0.4690 |
# ==> EarlyStop patience = 12 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 14 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 279.15it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 692.77it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    14
# Train_cost  = 0.6931 | Test_cost  = 0.6940 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 13 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 15 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 289.87it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 663.37it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    15
# Train_cost  = 0.6931 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 14 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 16 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 294.21it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 704.17it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    16
# Train_cost  = 0.6931 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 15 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 17 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 293.64it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 717.71it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    17
# Train_cost  = 0.6931 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 16 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 18 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 296.95it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 744.97it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    18
# Train_cost  = 0.6931 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 17 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 19 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 295.31it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 738.91it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    19
# Train_cost  = 0.6931 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 18 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 20 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 282.08it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 725.56it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6942 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    20
# Train_cost  = 0.6931 | Test_cost  = 0.6942 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 19 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 21 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 279.76it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 727.05it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6942 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    21
# Train_cost  = 0.6931 | Test_cost  = 0.6942 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 20 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 22 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 288.07it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 701.22it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6942 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    22
# Train_cost  = 0.6931 | Test_cost  = 0.6942 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 21 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 23 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 275.13it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 706.26it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    23
# Train_cost  = 0.6931 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 22 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 24 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 284.25it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 703.39it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    24
# Train_cost  = 0.6931 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 23 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 25 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 282.66it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 651.70it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    25
# Train_cost  = 0.6932 | Test_cost  = 0.6940 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 24 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 26 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 264.51it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 642.74it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    26
# Train_cost  = 0.6932 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 25 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 27 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 268.77it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 844.31it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6941 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    27
# Train_cost  = 0.6932 | Test_cost  = 0.6941 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 26 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 28 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 318.03it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 832.49it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    28
# Train_cost  = 0.6931 | Test_cost  = 0.6940 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 27 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 29 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 319.96it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 834.13it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6932 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    29
# Train_cost  = 0.6932 | Test_cost  = 0.6940 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 28 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 30 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 283.89it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 773.33it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    30
# Train_cost  = 0.6931 | Test_cost  = 0.6940 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 29 | Best test_score: 0.5000
# ─────────────────────────────────────────────────── 🚀 EPOCH 31 ───────────────────────────────────────────────────
# train: 100%|██████████| 173/173 [00:00<00:00, 318.65it/s]
# test: 100%|██████████| 45/45 [00:00<00:00, 786.01it/s]
#               📊 Summary                   🎯 Per-Label
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓       Accuracy
# ┃ Metric           ┃  Train ┃   Test ┃ ┏━━━━━━━┳━━━━━━━━━━┓
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩ ┃ Label ┃ Accuracy ┃
# │ Loss             │ 0.6931 │ 0.6940 │ ┡━━━━━━━╇━━━━━━━━━━┩
# │ Hamming Loss     │ 0.4954 │ 0.5310 │ │ green │  0.4690  │
# │ Subset Accuracy  │ 0.5046 │ 0.4690 │ │  red  │  0.4690  │
# │ Micro F1         │ 0.5046 │ 0.4690 │ └───────┴──────────┘
# │ Macro F1         │ 0.3354 │ 0.3193 │
# │ Overall Accuracy │ 0.5046 │ 0.4690 │
# └──────────────────┴────────┴────────┘
# Epoch    31
# Train_cost  = 0.6931 | Test_cost  = 0.6940 | Train_score = 0.5046 | Test_score = 0.4690 |
# ==> EarlyStop patience = 30 | Best test_score: 0.5000
# ==> Execute Early Stopping at epoch: 31 | Best test_score: 0.5000
# ==> Best model is saved at timeseris/multi-label-clasification/lstm/microsoft_stock_data/
# ⏹️ Training dihentikan oleh early stopping.

# %% [markdown]
# # Evaluate

# %%
from evaluate import evaluate_multi_label

hsl = evaluate_multi_label(model, test_loader, target_cols,criterion, device, config.threshold)
# Out:
#        📊 Evaluasi Model         🎯 Per-Label Accuracy
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━┳━━━━━━━━━┓
# ┃ Metrik              ┃  Nilai ┃ ┃  Label  ┃ Akurasi ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━╇━━━━━━━━━┩
# │ 🔹 Overall Accuracy │ 0.5000 │ │ y_green │ 0.4690  │
# │ ✅ Subset  Accuracy │ 0.0000 │ │  y_red  │ 0.5310  │
# │ 💥 Loss (avg)       │ 0.6971 │ └─────────┴─────────┘
# │ 📉 Hamming Loss     │ 0.5000 │
# │ ⚖️  Micro F1-score   │ 0.0000 │
# │ 📈 Macro F1-score   │ 0.0000 │
# └─────────────────────┴────────┘

# %%
hsl = hsl['df']
b = hsl[hsl['Benar (%)'] == 100]
b.head(300)
# Out:
# Empty DataFrame
# Columns: [Target, Prediksi, Benar (%)]
# Index: []

# %%
b.shape
# Out:
# (0, 3)

# %%
s = hsl[hsl['Benar (%)'] == 0]
s.head(300)
# Out:
# Empty DataFrame
# Columns: [Target, Prediksi, Benar (%)]
# Index: []

# %%
s.shape
# Out:
# (0, 3)
